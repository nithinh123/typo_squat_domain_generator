# %% [markdown]
# # 1) Without using online resources for this question, describe how you would go about trying to automate the detection of such domains? There are essentially 2 ways of doing.

# %% [raw]
# 1) Generate typesquatted domains using diffrent generation methods like addition, omission, replacement etc.
# 2) Validate the generated domain names by checking the registration details using 'whois' command.
# 3) Check for flagging of such domains using some online API's available.
# 4) Based on the registration details and the flagging details, categorise the domains as whether it is typesquatted or not.
# 5) Based on the categorization take necessory actions
#    -> For domains that are not registered, register that domain, so that in future attackers wont be able to use that for
#       malicious activities.
#    -> Taking legal actions as required for the domain's that are malicious.

# %% [markdown]
# # 2) Find a couple of commercial products that cover monitoring of typosquatted domains

# %% [raw]
# Product 1: BrandShield
#     Main features:
#     1)It uses AI and machine learning to detect and take down counterfeit or impersonated brand websites.
#     2)Protects brands across websites, mobile apps, and social media
#     3)Uses rule-based automated domain takedowns
#
#     Best for:
#         Modularity; you can get holistic coverage across several types of online properties or
#         simply opt for domain protection.
#
# Product 2: Bolster
#     Main features:
#     1)AI-based detection for phishing, brand infringement, scams, and typosquat attacks
#     2)Neutralizes threats without human intervention via automatic triage
#     3)Also monitors 12+ social media platforms and 400 app stores
#
#     Best for:
#         Rapid domain takedowns with minimal need for human intervention

# %% [markdown]
# # 3) Similarly, find a couple of open source products.

# %% [raw]
# Product 1: openSquat
#     Features:
#     1)Automatic newly registered domain updating (once a day)
#     2)Levenshtein distance to calculate word similarity
#     3)Fetches active and known phishing domains (Phishing Database project)
#     4)IDN homograph attack detection
#     5)Integration with VirusTotal
#     6)Integration with Quad9 DNS service
#     7)Use different levels of confidence threshold to fine tune
#     8)Save output into different formats (txt, JSON and CSV)
#     9)Can be integrated with other threat intelligence tools and DNS sinkholes
#
#
# Product 2: dnstwist
#     Features:
#     1)Variety of highly effective domain fuzzing algorithms
#     2)Unicode domain names (IDN)
#     3)Additional domain permutations from dictionary files
#     4)Efficient multithreaded task distribution
#     5)Live phishing webpage detection:
#         ->HTML similarity with fuzzy hashes (ssdeep/tlsh)
#         ->Screenshot visual similarity with perceptual hashes (pHash)
#     6)Rogue MX host detection (intercepting misdirected e-mails)
#     7)GeoIP location
#     8)Export to CSV and JSON

# %% [markdown]
# # 4) Discuss the pros and cons of the 2 methods

# %% [raw]
# Method 1: New domains are scraped every X hours and triaged according to their Levenshtein distances to the domain
#     they are potentially trying to typosquat, amongst other things.
#
#         Pros:
#             1) Scraping on a regular basis ensures that newly registered domains are evaluated as soon as possible,
#                 enabling for early detection of any typosquatting attempts.
#             2) Using Levenshtein distance as one of the triaging criteria enables automated initial evaluation,
#                 which can greatly minimise the effort for manual examination.
#
#         Cons:
#             1) While Levenshtein distance is useful, it may produce false positives by incorrectly detecting
#                 benign names with similar spellings to legal ones, as well as false negatives by potentially
#                 overlooking subtly typosquatted domains or those that impersonate legitimate ones using other tactics.
#             2) This approach is mostly used to detect typosquatting based on similar spellings. It may overlook other
#                 forms of typosquatting, such as homoglyph attacks or domains with physically identical characters.
#
# Method 2: Generate variants of a monitored domain (via additions, permutations, homoglyphs, bitsquatting, omissions,
#         insertions, repetitions, etc...) and check registration status and legitimacy of variant.
#
#         Pros:
#             1) This method can detect typosquatted domains independent of the precise method employed by attackers
#                 because it generates a large number of domain variants.
#             2) This strategy reduces the danger of false positives by validating the registration status and authenticity
#                 of each variant, as opposed to relying simply on similarity measures such as Levenshtein distance.
#             3) Generating potential domain names that remain unregistered presents a risk of future exploitation by attackers,
#                 which can be mitigated by proactively registering these domains.
#
#         Cons:
#             1) Creating and testing many domain variations can be computationally and time-consuming, especially for domains
#                 with long names or when utilising complicated techniques such as homoglyphs.
#             2) This method generates domain variants using well-known typosquatting strategies, which may miss out on new
#                 or unconventional methods being used by attackers.

# %% [markdown]
# # Prerequisite Python Packages
#
# ## Python Packages Used:
# ### pandas: for visualizing data in table
# ### selenium: for scraping data from website
# ### requests: for doing API calls and getting the response
# ### asyncio: for doing asynchronous actions in python
# ### aiohttp: asynchronous HTTP client/server framework built on top of asyncio
# ### Levenshtein: for calculating Levenshtein distance
# ### Flask: for creating the rest api for quering domain registration date and country

# %%
pip install pandas selenium==3.141.0 requests asyncio aiohttp Levenshtein Flask
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: selenium==3.141.0 in c:\users\nithi\appdata\roaming\python\python311\site-packages (3.141.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: asyncio in c:\users\nithi\appdata\roaming\python\python311\site-packages (3.4.3)
# Requirement already satisfied: aiohttp in c:\programdata\anaconda3\lib\site-packages (3.8.5)
# Requirement already satisfied: Levenshtein in c:\users\nithi\appdata\roaming\python\python311\site-packages (0.25.1)
# Requirement already satisfied: Flask in c:\programdata\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: urllib3 in c:\programdata\anaconda3\lib\site-packages (from selenium==3.141.0) (1.26.16)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\programdata\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests) (2023.11.17)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\nithi\appdata\roaming\python\python311\site-packages (from aiohttp) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\programdata\anaconda3\lib\site-packages (from aiohttp) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp) (1.2.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.8.0 in c:\users\nithi\appdata\roaming\python\python311\site-packages (from Levenshtein) (3.8.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\programdata\anaconda3\lib\site-packages (from Flask) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\programdata\anaconda3\lib\site-packages (from Flask) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\programdata\anaconda3\lib\site-packages (from Flask) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\programdata\anaconda3\lib\site-packages (from Flask) (8.0.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=8.0->Flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask) (2.1.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# # Data for homoglyph replacement mapping

# %%
SIMILAR_CHAR = {
    '0': ['o'],
    '1': ['l', 'i', 'ı'],
    '2': ['ƻ'],
    '5': ['ƽ'],
    'a': ['à', 'á', 'à', 'â', 'ã', 'ä', 'å', 'ɑ', 'ạ', 'ǎ', 'ă', 'ȧ', 'ą', 'ə'],
    'b': ['d', 'ʙ', 'ɓ', 'ḃ', 'ḅ', 'ḇ', 'ƅ'],
    'c': ['e', 'ƈ', 'ċ', 'ć', 'ç', 'č', 'ĉ', 'ᴄ'],
    'd': ['b', 'cl', 'ɗ', 'đ', 'ď', 'ɖ', 'ḑ', 'ḋ', 'ḍ', 'ḏ', 'ḓ'],
    'e': ['c', 'é', 'è', 'ê', 'ë', 'ē', 'ĕ', 'ě', 'ė', 'ẹ', 'ę', 'ȩ', 'ɇ', 'ḛ'],
    'f': ['ƒ', 'ḟ'],
    'g': ['q', 'ɢ', 'ɡ', 'ġ', 'ğ', 'ǵ', 'ģ', 'ĝ', 'ǧ', 'ǥ'],
    'h': ['ĥ', 'ȟ', 'ħ', 'ɦ', 'ḧ', 'ḩ', 'ⱨ', 'ḣ', 'ḥ', 'ḫ', 'ẖ'],
    'i': ['1', 'l', 'í', 'ì', 'ï', 'ı', 'ɩ', 'ǐ', 'ĭ', 'ỉ', 'ị', 'ɨ', 'ȋ', 'ī', 'ɪ'],
    'j': ['ʝ', 'ǰ', 'ɉ', 'ĵ'],
    'k': ['lc', 'ḳ', 'ḵ', 'ⱪ', 'ķ', 'ᴋ'],
    'l': ['1', 'i', 'ɫ', 'ł', 'ı', 'ɩ'],
    'm': ['n', 'nn', 'rn', 'rr', 'ṁ', 'ṃ', 'ᴍ', 'ɱ', 'ḿ'],
    'n': ['m', 'r', 'ń', 'ṅ', 'ṇ', 'ṉ', 'ñ', 'ņ', 'ǹ', 'ň', 'ꞑ'],
    'o': ['0', 'ȯ', 'ọ', 'ỏ', 'ơ', 'ó', 'ö', 'ᴏ'],
    'p': ['ƿ', 'ƥ', 'ṕ', 'ṗ'],
    'q': ['g', 'ʠ'],
    'r': ['ʀ', 'ɼ', 'ɽ', 'ŕ', 'ŗ', 'ř', 'ɍ', 'ɾ', 'ȓ', 'ȑ', 'ṙ', 'ṛ', 'ṟ'],
    's': ['ʂ', 'ś', 'ṣ', 'ṡ', 'ș', 'ŝ', 'š', 'ꜱ'],
    't': ['ţ', 'ŧ', 'ṫ', 'ṭ', 'ț', 'ƫ'],
    'u': ['ᴜ', 'ǔ', 'ŭ', 'ü', 'ʉ', 'ù', 'ú', 'û', 'ũ', 'ū', 'ų', 'ư', 'ů', 'ű', 'ȕ', 'ȗ', 'ụ'],
    'v': ['ṿ', 'ⱱ', 'ᶌ', 'ṽ', 'ⱴ', 'ᴠ'],
    'w': ['vv', 'ŵ', 'ẁ', 'ẃ', 'ẅ', 'ⱳ', 'ẇ', 'ẉ', 'ẘ', 'ᴡ'],
    'x': ['ẋ', 'ẍ'],
    'y': ['ʏ', 'ý', 'ÿ', 'ŷ', 'ƴ', 'ȳ', 'ɏ', 'ỿ', 'ẏ', 'ỵ'],
    'z': ['ʐ', 'ż', 'ź', 'ᴢ', 'ƶ', 'ẓ', 'ẕ', 'ⱬ']
}

# %% [markdown]
# # Code for generating variants of a monitored domain using addition, omission, replacement, repetition, homoglyps and bit squatting.

# %%
"""
    Module for generating variants of a monitored domain

"""

import tldextract


class GenerateDomainName:
    """
    A class to generate domain names using
    diffrent type squatting methods

    ...

    Attributes
    ----------
    domain : str
        domain that need to be searched for
        Typosquatting related entries

    Methods
    -------
    parse_domain():
        parse a domain into three parts domain_prefix,
        domain_without_tld and domain_tld

    append_prefix_suffix():
        appends domain_prefix and domain_tld to domain name

    get_letters_numbers():
        generates numbers [0-9] and letter [a-z]

    addition():
        adds single characters from [a-z] and [0-9]
        to the domain name

    omission():
        removes a charactor from the domain name

    repetition():
        using all characters that already exists in the
        domain name one by one to create new domain name

    replacement():
        replaces a charactor in the domain name

    replace_char():
        replaces a charactor with multiple occurrence
        one at a time in a string with another charactor

    homoglyphs():
        replaces all possible homoglyphs using
        the mapping data

    bit_squatting():
        flips the jTh bit in iTh charactor of any domain to
        generate multiple possible bit-squatting

    main():
        main method that calls all the
        functions to generate domain names

    """

    def __init__(self, domain: str):
        self.domain = domain
        prefix, domain_name, tld = self.parse_domain()
        self.domain_prefix = prefix
        self.domain_name = domain_name
        self.domain_tld = tld
        self.domain_list = []

    def parse_domain(self) -> tuple:
        """
            This method splits domain to domain_prefix,
            domain_without_tld and domain_tld

        Returns:
            tuple: domain_prefix, domain_without_tld, domain_tld
        """
        domain_extract = tldextract.extract(self.domain)
        domain_prefix = domain_extract.subdomain + "."
        domain_without_tld = domain_extract.domain
        domain_tld = "." + domain_extract.suffix
        return domain_prefix, domain_without_tld, domain_tld

    def append_prefix_suffix(self, name: str) -> str:
        """
            This method appends the domain prefix and tld
            to generated domain name

        Returns:
            list: domain name with prefix and tld
        """
        return self.domain_prefix + name + self.domain_tld

    @staticmethod
    def get_letters_numbers() -> list:
        """
            This method generates numbers [0-9] and letter [a-z]

        Returns:
            list: list of numbers [0-9] and letters [a-z]
        """
        number_strings = [str(i) for i in range(10)]
        letter_strings = [chr(ord('a') + i) for i in range(26)]
        combined_list = number_strings + letter_strings
        return combined_list

    def addition(self) -> list:
        """
            This method adds single characters from [a-z] and [0-9]
            to the domain name to create possible domain names

        Returns:
            list: list of type squatted domains
        """
        combined_list = self.get_letters_numbers()
        for addition_string in combined_list:
            for j in range(0, len(self.domain_name)):
                domain_variation = self.append_prefix_suffix(self.domain_name[:j] + \
                                                             addition_string + self.domain_name[j:])
                if domain_variation not in self.domain_list:
                    self.domain_list.append(domain_variation)
                if j == len(self.domain_name) - 1:
                    domain_variation = self.append_prefix_suffix(self.domain_name + \
                                                                 addition_string)
                    self.domain_list.append(domain_variation)
        return self.domain_list

    def omission(self) -> list:
        """
            This method removes a charactor from the domain name
            to create possible domain names

        Returns:
            list: list of type squatted domains
        """
        for i in range(0, len(self.domain_name)):
            domain_variation = self.append_prefix_suffix(self.domain_name[0:i] +
                                self.domain_name[i + 1:len(self.domain_name)])
            if domain_variation not in self.domain_list:
                self.domain_list.append(domain_variation)
        return self.domain_list

    def repetition(self) -> list:
        """
            This method uses all characters that already exists in the
            domain name one by one to create possible domain names

        Returns:
            list: list of type squatted domains
        """
        for i, letter in enumerate(self.domain_name):
            domain_variation = self.append_prefix_suffix(self.domain_name[:i]
                                                         + letter + self.domain_name[i:])
            if domain_variation not in self.domain_list:
                self.domain_list.append(domain_variation)
        return self.domain_list

    def replacement(self) -> list:
        """
            This method replaces a charactor in the domain name
            to create possible domain names

        Returns:
            list: list of type squatted domains
        """
        letters_numbers = self.get_letters_numbers()
        for replacement_string in letters_numbers:
            for j in range(0, len(self.domain_name)):
                first = self.domain_name[:j]
                last = self.domain_name[j + 1:]
                domain_variation = self.append_prefix_suffix(first + 
                                            replacement_string + last)
                if domain_variation not in self.domain_list:
                    self.domain_list.append(domain_variation)
        return self.domain_list

    @staticmethod
    def replace_char(original_string: str, target: str, replacement: str) -> list:
        """
            This method replaces a charactor with multiple occurrence
            one at a time in a string with another charactor

        Returns:
            list: list of possible strings after replacement
        """
        index = []
        new_strings = []
        for i, char in enumerate(original_string):
            if char == target:
                index.append(i)
        for item in index:
            if item != -1:
                new_string = original_string[:item] + replacement + \
                            original_string[item + 1:]
                new_strings.append(new_string)
            else:
                return [original_string]
        return new_strings

    def homoglyphs(self) -> list:
        """
            This method replaces all possible homoglyphs using
            the mapping data to create possible domain names

        Returns:
            list: list of type squatted domains
        """
        for item in self.domain_name:
            if item in SIMILAR_CHAR:
                for glyph in SIMILAR_CHAR[item]:
                    modified_domains = self.replace_char(self.domain_name,
                                                         item, glyph)
                    for modified_domain in modified_domains:
                        domain_variation = self.append_prefix_suffix(modified_domain)
                        if domain_variation not in self.domain_list:
                            self.domain_list.append(domain_variation)
        return self.domain_list

    def bit_squatting(self) -> list:
        """
            This method flips the jTh bit in iTh charactor of any domain to
            generate multiple possible bit-squatting

        Returns:
            list: list of type squatted domains
        """
        for i, _ in enumerate(self.domain_name):
            for j in range(8):
                bit_squatted_char = chr(ord(self.domain_name[i]) ^ (1 << j))
                if bit_squatted_char.isalnum():
                    domain_variation = self.append_prefix_suffix(
                        self.domain_name[:i] + bit_squatted_char + self.domain_name[i + 1:])
                    if domain_variation not in self.domain_list:
                        self.domain_list.append(domain_variation)
        return self.domain_list

    def main(self) -> list:
        """
            This method is the main method that calls all the
            functions to generate domain names

        Returns:
            list: list of type squatted domains
        """
        self.addition()
        self.omission()
        self.repetition()
        self.replacement()
        self.homoglyphs()
        self.bit_squatting()
        return self.domain_list


if __name__ == '__main__':
    possible_data = GenerateDomainName("www.google.com").main()
    print(possible_data)
# Out:
# ['www.0google.com', 'www.g0oogle.com', 'www.go0ogle.com', 'www.goo0gle.com', 'www.goog0le.com', 'www.googl0e.com', 'www.google0.com', 'www.1google.com', 'www.g1oogle.com', 'www.go1ogle.com', 'www.goo1gle.com', 'www.goog1le.com', 'www.googl1e.com', 'www.google1.com', 'www.2google.com', 'www.g2oogle.com', 'www.go2ogle.com', 'www.goo2gle.com', 'www.goog2le.com', 'www.googl2e.com', 'www.google2.com', 'www.3google.com', 'www.g3oogle.com', 'www.go3ogle.com', 'www.goo3gle.com', 'www.goog3le.com', 'www.googl3e.com', 'www.google3.com', 'www.4google.com', 'www.g4oogle.com', 'www.go4ogle.com', 'www.goo4gle.com', 'www.goog4le.com', 'www.googl4e.com', 'www.google4.com', 'www.5google.com', 'www.g5oogle.com', 'www.go5ogle.com', 'www.goo5gle.com', 'www.goog5le.com', 'www.googl5e.com', 'www.google5.com', 'www.6google.com', 'www.g6oogle.com', 'www.go6ogle.com', 'www.goo6gle.com', 'www.goog6le.com', 'www.googl6e.com', 'www.google6.com', 'www.7google.com', 'www.g7oogle.com', 'www.go7ogle.com', 'www.goo7gle.com', 'www.goog7le.com', 'www.googl7e.com', 'www.google7.com', 'www.8google.com', 'www.g8oogle.com', 'www.go8ogle.com', 'www.goo8gle.com', 'www.goog8le.com', 'www.googl8e.com', 'www.google8.com', 'www.9google.com', 'www.g9oogle.com', 'www.go9ogle.com', 'www.goo9gle.com', 'www.goog9le.com', 'www.googl9e.com', 'www.google9.com', 'www.agoogle.com', 'www.gaoogle.com', 'www.goaogle.com', 'www.gooagle.com', 'www.googale.com', 'www.googlae.com', 'www.googlea.com', 'www.bgoogle.com', 'www.gboogle.com', 'www.gobogle.com', 'www.goobgle.com', 'www.googble.com', 'www.googlbe.com', 'www.googleb.com', 'www.cgoogle.com', 'www.gcoogle.com', 'www.gocogle.com', 'www.goocgle.com', 'www.googcle.com', 'www.googlce.com', 'www.googlec.com', 'www.dgoogle.com', 'www.gdoogle.com', 'www.godogle.com', 'www.goodgle.com', 'www.googdle.com', 'www.googlde.com', 'www.googled.com', 'www.egoogle.com', 'www.geoogle.com', 'www.goeogle.com', 'www.gooegle.com', 'www.googele.com', 'www.googlee.com', 'www.googlee.com', 'www.fgoogle.com', 'www.gfoogle.com', 'www.gofogle.com', 'www.goofgle.com', 'www.googfle.com', 'www.googlfe.com', 'www.googlef.com', 'www.ggoogle.com', 'www.gogogle.com', 'www.googgle.com', 'www.googlge.com', 'www.googleg.com', 'www.hgoogle.com', 'www.ghoogle.com', 'www.gohogle.com', 'www.goohgle.com', 'www.googhle.com', 'www.googlhe.com', 'www.googleh.com', 'www.igoogle.com', 'www.gioogle.com', 'www.goiogle.com', 'www.gooigle.com', 'www.googile.com', 'www.googlie.com', 'www.googlei.com', 'www.jgoogle.com', 'www.gjoogle.com', 'www.gojogle.com', 'www.goojgle.com', 'www.googjle.com', 'www.googlje.com', 'www.googlej.com', 'www.kgoogle.com', 'www.gkoogle.com', 'www.gokogle.com', 'www.gookgle.com', 'www.googkle.com', 'www.googlke.com', 'www.googlek.com', 'www.lgoogle.com', 'www.gloogle.com', 'www.gologle.com', 'www.goolgle.com', 'www.googlle.com', 'www.googlel.com', 'www.mgoogle.com', 'www.gmoogle.com', 'www.gomogle.com', 'www.goomgle.com', 'www.googmle.com', 'www.googlme.com', 'www.googlem.com', 'www.ngoogle.com', 'www.gnoogle.com', 'www.gonogle.com', 'www.goongle.com', 'www.goognle.com', 'www.googlne.com', 'www.googlen.com', 'www.ogoogle.com', 'www.gooogle.com', 'www.googole.com', 'www.googloe.com', 'www.googleo.com', 'www.pgoogle.com', 'www.gpoogle.com', 'www.gopogle.com', 'www.goopgle.com', 'www.googple.com', 'www.googlpe.com', 'www.googlep.com', 'www.qgoogle.com', 'www.gqoogle.com', 'www.goqogle.com', 'www.gooqgle.com', 'www.googqle.com', 'www.googlqe.com', 'www.googleq.com', 'www.rgoogle.com', 'www.groogle.com', 'www.gorogle.com', 'www.goorgle.com', 'www.googrle.com', 'www.googlre.com', 'www.googler.com', 'www.sgoogle.com', 'www.gsoogle.com', 'www.gosogle.com', 'www.goosgle.com', 'www.googsle.com', 'www.googlse.com', 'www.googles.com', 'www.tgoogle.com', 'www.gtoogle.com', 'www.gotogle.com', 'www.gootgle.com', 'www.googtle.com', 'www.googlte.com', 'www.googlet.com', 'www.ugoogle.com', 'www.guoogle.com', 'www.gouogle.com', 'www.goougle.com', 'www.googule.com', 'www.goog ...

# %%
#list of generated domains using addition, omission, replacement, repetition, homoglyps and bit squatting
possible_data
# Out:
# ['www.0google.com',
#  'www.g0oogle.com',
#  'www.go0ogle.com',
#  'www.goo0gle.com',
#  'www.goog0le.com',
#  'www.googl0e.com',
#  'www.google0.com',
#  'www.1google.com',
#  'www.g1oogle.com',
#  'www.go1ogle.com',
#  'www.goo1gle.com',
#  'www.goog1le.com',
#  'www.googl1e.com',
#  'www.google1.com',
#  'www.2google.com',
#  'www.g2oogle.com',
#  'www.go2ogle.com',
#  'www.goo2gle.com',
#  'www.goog2le.com',
#  'www.googl2e.com',
#  'www.google2.com',
#  'www.3google.com',
#  'www.g3oogle.com',
#  'www.go3ogle.com',
#  'www.goo3gle.com',
#  'www.goog3le.com',
#  'www.googl3e.com',
#  'www.google3.com',
#  'www.4google.com',
#  'www.g4oogle.com',
#  'www.go4ogle.com',
#  'www.goo4gle.com',
#  'www.goog4le.com',
#  'www.googl4e.com',
#  'www.google4.com',
#  'www.5google.com',
#  'www.g5oogle.com',
#  'www.go5ogle.com',
#  'www.goo5gle.com',
#  'www.goog5le.com',
#  'www.googl5e.com',
#  'www.google5.com',
#  'www.6google.com',
#  'www.g6oogle.com',
#  'www.go6ogle.com',
#  'www.goo6gle.com',
#  'www.goog6le.com',
#  'www.googl6e.com',
#  'www.google6.com',
#  'www.7google.com',
#  'www.g7oogle.com',
#  'www.go7ogle.com',
#  'www.goo7gle.com',
#  'www.goog7le.com',
#  'www.googl7e.com',
#  'www.google7.com',
#  'www.8google.com',
#  'www.g8oogle.com',
#  'www.go8ogle.com',
#  'www.goo8gle.com',
#  'www.goog8le.com',
#  'www.googl8e.com',
#  'www.google8.com',
#  'www.9google.com',
#  'www.g9oogle.com',
#  'www.go9ogle.com',
#  'www.goo9gle.com',
#  'www.goog9le.com',
#  'www.googl9e.com',
#  'www.google9.com',
#  'www.agoogle.com',
#  'www.gaoogle.com',
#  'www.goaogle.com',
#  'www.gooagle.com',
#  'www.googale.com',
#  'www.googlae.com',
#  'www.googlea.com',
#  'www.bgoogle.com',
#  'www.gboogle.com',
#  'www.gobogle.com',
#  'www.goobgle.com',
#  'www.googble.com',
#  'www.googlbe.com',
#  'www.googleb.com',
#  'www.cgoogle.com',
#  'www.gcoogle.com',
#  'www.gocogle.com',
#  'www.goocgle.com',
#  'www.googcle.com',
#  'www.googlce.com',
#  'www.googlec.com',
#  'www.dgoogle.com',
#  'www.gdoogle.com',
#  'www.godogle.com',
#  'www.goodgle.com',
#  'www.googdle.com',
#  'www.googlde.com',
#  'www.googled.com',
#  'www.egoogle.com',
#  'www.geoogle.com',
#  'www.goeogle.com',
#  'www.gooegle.com',
#  'www.googele.com',
#  'www.googlee.com',
#  'www.googlee.com',
#  'www.fgoogle.com',
#  'www.gfoogle.com',
#  'www.gofogle.com',
#  'www.goofgle.com',
#  'www.googfle.com',
#  'www.googlfe.com',
#  'www.googlef.com',
#  'www.ggoogle.com',
#  'www.gogogle.com',
#  'www.googgle.com',
#  'www.googlge.com',
#  'www.googleg.com',
#  'www.hgoogle.com',
#  'www.ghoogle.com',
#  'www.gohogle.com',
#  'www.goohgle.com',
#  'www.googhle.com',
#  'www.googlhe.com',
#  'www.googleh.com',
#  'www.igoogle.com',
#  'www.gioogle.com',
#  'www.goiogle.com',
#  'www.gooigle.com',
#  'www.googile.com',
#  'www.googlie.com',
#  'www.googlei.com',
#  'www.jgoogle.com',
#  'www.gjoogle.com',
#  'www.gojogle.com',
#  'www.goojgle.com',
#  'www.googjle.com',
#  'www.googlje.com',
#  'www.googlej.com',
#  'www.kgoogle.com',
#  'www.gkoogle.com',
#  'www.gokogle.com',
#  'www.gookgle.com',
#  'www.googkle.com',
#  'www.googlke.com',
#  'www.googlek.com',
#  'www.lgoogle.com',
#  'www.gloogle.com',
#  'www.gologle.com',
#  'www.goolgle.com',
#  'www.googlle.com',
#  'www.googlel.com',
#  'www.mgoogle.com',
#  'www.gmoogle.com',
#  'www.gomogle.com',
#  'www.goomgle.com',
#  'www.googmle.com',
#  'www.googlme.com',
#  'www.googlem.com',
#  'www.ngoogle.com',
#  'www.gnoogle.com',
#  'www.gonogle.com',
#  'www.goongle.com',
#  'www.goognle.com',
#  'www.googlne.com',
#  'www.googlen.com',
#  'www.ogoogle.com',
#  'www.gooogle.com',
#  'www.googole.com',
#  'www.googloe.com',
#  'www.googleo.com',
#  'www.pgoogle.com',
#  'www.gpoogle.com',
#  'www.gopogle.com',
#  'www.goopgle.com',
#  'www.googple.com',
#  'www.googlpe.com',
#  'www.googlep.com',
#  'www.qgoogle.com',
#  'www.gqoogle.com',
#  'www.goqogle.com',
#  'www.gooqgle.com',
#  'www.googqle.com',
#  'www.googlqe.com',
#  'www.googleq.com',
#  'www.rgoogle.com',
#  'www.groogle.com',
#  'www.gorogle.com',
#  'www.goorgle.com',
#  'www.googrle.com',
#  'www.googlre.com',
#  'www.googler.com',
#  'www.sgoogle.com',
#  'www.gsoogle.com',
#  'www.gosogle.com',
#  'www.goosgle.com',
#  'www.googsle.com',
#  'www.googlse.com',
#  'www.googles.com',
#  'www.tgoogle.com',
#  'www.gtoogle.com',
#  'www.gotogle.com',
#  'www.gootgle.com',
#  'www.googtle.com',
#  'www.googlte.com',
#  'www.googlet.com',
#  'www.ugoogle.com',
#  'www.guoogle.com',
#  'www.gouogle.com',
#  'www.goougle.com',
#  'www.googule.com',
#  'www.googlue.com',
#  'www.googleu.com',
#  'www.vgoogle.com',
#  'www.gvoogle.com',
#  'www.govogle.com',
#  'www.goovgle.com',
#  'www.googvle.com',
#  'www.googlve.com',
#  'www.googlev.com',
#  'www.wgoogle.com',
#  'www.gwoogle.com',
#  'www.gowogle.com',
#  'www.goowgle.com',
#  'www.googwle.com',
#  'www.googlwe.com',
#  'www.googlew.com',
#  'www.xgoogle.com',
#  'www.gxoogle.com',
#  'www.goxogle.com',
#  'www.gooxgle.com',
#  'www.googxle.com',
#  'www.googlxe.com',
#  'www.googlex.com',
#  'www.ygoogle.com',
#  'www.gyoogle.com',
#  'www.goyogle.com',
#  'www.gooygle.com',
#  'www.googyle.com',
#  'www.googlye.com',
#  'www.googley.com',
#  'www.zgoogle.com',
#  'www.gzoogle.com',
#  'www.gozogle.com',
#  'www.goozgle.com',
#  'www.googzle.com',
#  'www.googlze.com',
#  'www.googlez.com',
#  'www.oogle.com',
#  'www.gogle.com',
#  'www.goole.com',
#  'www.googe.com',
#  'www.googl.com',
#  'www.0oogle.com',
#  'www.g0ogle.com',
#  'www.go0gle.com',
#  'www.goo0le.com',
#  'www.goog0e.com',
#  'www.googl0.com',
#  'www.1oogle.com',
#  'www.g1ogle.com',
#  'www.go1gle.com',
#  'www.goo1le.com',
#  'www.goog1e.com',
#  'www.googl1.com',
#  'www.2oogle.com',
#  'www.g2ogle.com',
#  'www.go2gle.com',
#  'www.goo2le.com',
#  'www.goog2e.com',
#  'www.googl2.com',
#  'www.3oogle.com',
#  'www.g3ogle.com',
#  'www.go3gle.com',
#  'www.goo3le.com',
#  'www.goog3e.com',
#  'www.googl3.com',
#  'www.4oogle.com',
#  'www.g4ogle.com',
#  'www.go4gle.com',
#  'www.goo4le.com',
#  'www.goog4e.com',
#  'www.googl4.com',
#  'www.5oogle.com',
#  'www.g5ogle.com',
#  'www.go5gle.com',
#  'www.goo5le.com',
#  'www.goog5e.com',
#  'www.googl5.com',
#  'www.6oogle.com',
#  'www.g6ogle.com',
#  'www.go6gle.com',
#  'www.goo6le.com',
#  'www.goog6e.com',
#  'www.googl6.com',
#  'www.7oogle.com',
#  'www.g7ogle.com',
#  'www.go7gle.com',
#  'www.goo7le.com',
#  'www.goog7e.com',
#  'www.googl7.com',
#  'www.8oogle.com',
#  'www.g8ogle.com',
#  'www.go8gle.com',
#  'www.goo8le.com',
#  'www.goog8e.com',
#  'www.googl8.com',
#  'www.9oogle.com',
#  'www.g9ogle.com',
#  'www.go9gle.com',
#  'www.goo9le.com',
#  'www.goog9e.com',
#  'www.googl9.com',
#  'www.aoogle.com',
#  'www.gaogle.com',
#  'www.goagle.com',
#  'www.gooale.com',
#  'www.googae.com',
#  'www.googla.com',
#  'www.boogle.com',
#  'www.gbogle.com',
#  'www.gobgle.com',
#  'www.gooble.com',
#  'www.googbe.com',
#  'www.googlb.com',
#  'www.coogle.com',
#  'www.gcogle.com',
#  'www.gocgle.com',
#  'www.goocle.com',
#  'www.googce.com',
#  'www.googlc.com',
#  'www.doogle.com',
#  'www.gdogle.com',
#  'www.godgle.com',
#  'www.goodle.com',
#  'www.googde.com',
#  'www.googld.com',
#  'www.eoogle.com',
#  'www.geogle.com',
#  'www.goegle.com',
#  'www.gooele.com',
#  'www.googee.com',
#  'www.google.com',
#  'www.foogle.com',
#  'www.gfogle.com',
#  'www.gofgle.com',
#  'www.goofle.com',
#  'www.googfe.com',
#  'www.googlf.com',
#  'www.ggogle.com',
#  'www.goggle.com',
#  'www.googge.com',
#  'www.googlg.com',
#  'www.hoogle.com',
#  'www.ghogle.com',
#  'www.gohgle.com',
#  'www.goohle.com',
#  'www.googhe.com',
#  'www.googlh.com',
#  'www.ioogle.com',
#  'www.giogle.com',
#  'www.goigle.com',
#  'www.gooile.com',
#  'www.googie.com',
#  'www.googli.com',
#  'www.joogle.com',
#  'www.gjogle.com',
#  'www.gojgle.com',
#  'www.goojle.com',
#  'www.googje.com',
#  'www.googlj.com',
#  'www.koogle.com',
#  'www.gkogle.com',
#  'www.gokgle.com',
#  'www.gookle.com',
#  'www.googke.com',
#  'www.googlk.com',
#  'www.loogle.com',
#  'www.glogle.com',
#  'www.golgle.com',
#  'www.goolle.com',
#  'www.googll.com',
#  'www.moogle.com',
#  'www.gmogle.com',
#  'www.gomgle.com',
#  'www.goomle.com',
#  'www.googme.com',
#  'www.googlm.com',
#  'www.noogle.com',
#  'www.gnogle.com',
#  'www.gongle.com',
#  'www.goonle.com',
#  'www.googne.com',
#  'www.googln.com',
#  'www.ooogle.com',
#  'www.gooole.com',
#  'www.googoe.com',
#  'www.googlo.com',
#  'www.poogle.com',
#  'www.gpogle.com',
#  'www.gopgle.com',
#  'www.goople.com',
#  'www.googpe.com',
#  'www.googlp.com',
#  'www.qoogle.com',
#  'www.gqogle.com',
#  'www.goqgle.com',
#  'www.gooqle.com',
#  'www.googqe.com',
#  'www.googlq.com',
#  'www.roogle.com',
#  'www.grogle.com',
#  'www.gorgle.com',
#  'www.goorle.com',
#  'www.googre.com',
#  'www.googlr.com',
#  'www.soogle.com',
#  'www.gsogle.com',
#  'www.gosgle.com',
#  'www.goosle.com',
#  'www.googse.com',
#  'www.googls.com',
#  'www.toogle.com',
#  'www.gtogle.com',
#  'www.gotgle.com',
#  'www.gootle.com',
#  'www.googte.com',
#  'www.googlt.com',
#  'www.uoogle.com',
#  'www.guogle.com',
#  'www.gougle.com',
#  'www.gooule.com',
#  'www.googue.com',
#  'www.googlu.com',
#  'www.voogle.com',
#  'www.gvogle.com',
#  'www.govgle.com',
#  'www.goovle.com',
#  'www.googve.com',
#  'www.googlv.com',
#  'www.woogle.com',
#  'www.gwogle.com',
#  'www.gowgle.com',
#  'www.goowle.com',
#  'www.googwe.com',
#  'www.googlw.com',
#  'www.xoogle.com',
#  'www.gxogle.com',
#  'www.goxgle.com',
#  'www.gooxle.com',
#  'www.googxe.com',
#  'www.googlx.com',
#  'www.yoogle.com',
#  'www.gyogle.com',
#  'www.goygle.com',
#  'www.gooyle.com',
#  'www.googye.com',
#  'www.googly.com',
#  'www.zoogle.com',
#  'www.gzogle.com',
#  'www.gozgle.com',
#  'www.goozle.com',
#  'www.googze.com',
#  'www.googlz.com',
#  'www.ɢoogle.com',
#  'www.gooɢle.com',
#  'www.ɡoogle.com',
#  'www.gooɡle.com',
#  'www.ġoogle.com',
#  'www.gooġle.com',
#  'www.ğoogle.com',
#  'www.gooğle.com',
#  'www.ǵoogle.com',
#  'www.gooǵle.com',
#  'www.ģoogle.com',
#  'www.gooģle.com',
#  'www.ĝoogle.com',
#  'www.gooĝle.com',
#  'www.ǧoogle.com',
#  'www.gooǧle.com',
#  'www.ǥoogle.com',
#  'www.gooǥle.com',
#  'www.gȯogle.com',
#  'www.goȯgle.com',
#  'www.gọogle.com',
#  'www.goọgle.com',
#  'www.gỏogle.com',
#  'www.goỏgle.com',
#  'www.gơogle.com',
#  'www.goơgle.com',
#  'www.góogle.com',
#  'www.goógle.com',
#  'www.göogle.com',
#  'www.goögle.com',
#  'www.gᴏogle.com',
#  'www.goᴏgle.com',
#  'www.googɫe.com',
#  'www.googłe.com',
#  'www.googıe.com',
#  'www.googɩe.com',
#  'www.googlé.com',
#  'www.googlè.com',
#  'www.googlê.com',
#  'www.googlë.com',
#  'www.googlē.com',
#  'www.googlĕ.com',
#  'www.googlě.com',
#  'www.googlė.com',
#  'www.googlẹ.com',
#  'www.googlę.com',
#  'www.googlȩ.com',
#  'www.googlɇ.com',
#  'www.googlḛ.com',
#  'www.Google.com',
#  'www.çoogle.com',
#  'www.gOogle.com',
#  'www.gïogle.com',
#  'www.goOgle.com',
#  'www.goïgle.com',
#  'www.gooGle.com',
#  'www.gooçle.com',
#  'www.googLe.com',
#  'www.googìe.com',
#  'www.googlE.com',
#  'www.googlå.com']

# %% [markdown]
# # Web Scraping Code
#
# ### 1) This website takes some time to load the data based on the domain that we are trying to check.
# ### 2) Once the data is loaded, data is scraped from the site based on class which is "domain-row resolved"
# ### 3) Domain with punycode is also pulled and puny coded domain details are also attached in the final data.
# ### 4) Data is processed and returned in the form of list of dictionary and the status and message of the code    execution status
#
# ## Note:
# ### This code uses selenium to scape data from dnstwister.report website which is tested with Chrome Browser.
# ### Code is tested with Chrome Version 123.0.6312.122 and Chrome webdriver version 123.

# %%
"""
    Module for getting report of a domain of your choice
    from https://dnstwister.report and scrape the required 
    details.

"""
import re
import idna
import json
import binascii
import ipaddress
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

DNSTWISTER_ENDPOINT = "https://dnstwister.report"
SUPPORTED_BROWSERS = ["chrome", "firefox", "edge"]


class ScrapeData:
    """
    A class to scrap data from dnsteister website

    ...

    Attributes
    ----------
    domain : str
        domain url that need to be searched for 
        Typosquatting related entries
    browser : str
        name of the browser that is supported.
        supported browsers are: 
        1) firefox 
        2) chrome
        3) edge

    Methods
    -------
    get_driver():
        get the driver for supported browser

    scrap_domain_data():
        scrap domain data of the domain that is passed
        
    encode_domain_name():
        encodes the domain name
    """

    def __init__(self, domain: str, browser: str):
        self.domain = domain
        self.browser = browser

    def get_driver(self):
        """
            This method checks for the driver input and 
            returns the driver if it is supported

        Returns:
            Returns a status(boolean) and 
            driver details if browser is supported 
            or message if it is not supported
        """
        if self.browser in SUPPORTED_BROWSERS:
            if self.browser == "chrome":
                return True, webdriver.Chrome()
            elif self.browser == "edge":
                return True, webdriver.Edge()
            elif self.browser == "firefox":
                return True, webdriver.Firefox()
        return False, f"{self.browser} browser is not supported"

    def encode_domain_name(self) -> str:
        """
            This method returns encoded domain name for API usage
        
        """
        return binascii.hexlify(self.domain.encode()).decode()
    
    def scrape_domain_data(self) -> dict:
        """
            This method connects to browser and get domain
            related data from dnstwist website

        Returns:
            Returns a dictionary with status(boolean),
            a list of dictionary containing domain and ip,
            and message regarding the status

            Eg: 
                {"status": True,
                "data":[{'domain': 'www.google.com','ip': '172.217.16.228'},
                {'domain': 'login-google.com','ip': '199.231.164.178'}],
                "message": "Scraping completed successfully"}

            Eg:

                if browser not supported:

                {"status": False, "data":[],"message":"safari browser is not supported"}

                if some exception occurs:

                {"status": False, "data":[], "message":"Exception: <exception reason>"}
        """
        try:
            encoded_domain = self.encode_domain_name()
            url = f"{DNSTWISTER_ENDPOINT}/search?ed={encoded_domain}"
            status, driver = self.get_driver()
            if status:
                driver.get(url)
                WebDriverWait(driver, 60).until(EC.presence_of_element_located((By.LINK_TEXT, "export csv")))
                scrape_data = driver.find_elements_by_xpath('//tr[@class="domain-row resolved"]')
                processed_data = []
                for item in enumerate(scrape_data):
                    data = re.sub(r'\([^)]*\)', '', item[1].text)
                    data = data.replace('\n', ' ')
                    data = data.split(" ")
                    data = [x for x in data if x]
                    puny_code = idna.encode(data[0]).decode()
                    processed_data.append(
                        {
                        "domain": data[0], 
                        "puny_code_domain": puny_code if puny_code != data[0] else "",
                        "ip": data[1]
                        }
                    )
                driver.quit()
                return {"status": True, "data": processed_data,
                        "message": "Scraping completed successfully"}
            return {"status": False, "data": [], "message": driver}
        except Exception as e:
            return {"status": False, "data": [],"message": f"Exception: {str(e)}"}

if __name__ == "__main__":
    output = ScrapeData("www.google.com", "chrome").scrape_domain_data()
    print(output)
# Out:
# {'status': True, 'data': [{'domain': 'www.google.org', 'puny_code_domain': '', 'ip': '216.239.32.27'}, {'domain': 'ww.google.com', 'puny_code_domain': '', 'ip': '142.250.200.46'}, {'domain': 'www.google.co', 'puny_code_domain': '', 'ip': '142.250.187.206'}, {'domain': 'www.google.net', 'puny_code_domain': '', 'ip': '142.250.200.36'}, {'domain': 'www.google.de', 'puny_code_domain': '', 'ip': '172.217.16.227'}, {'domain': 'www.google.tk', 'puny_code_domain': '', 'ip': '142.250.200.3'}, {'domain': 'wwwngoogle.com', 'puny_code_domain': '', 'ip': '199.59.243.225'}, {'domain': 'wwwgoogle.com', 'puny_code_domain': '', 'ip': '216.58.212.228'}, {'domain': 'www.go0ogle.com', 'puny_code_domain': '', 'ip': '95.211.189.138'}, {'domain': 'www.gookgle.com', 'puny_code_domain': '', 'ip': '103.224.182.226'}, {'domain': 'wwwg.oogle.com', 'puny_code_domain': '', 'ip': '104.21.19.57'}, {'domain': 'www.googlwe.com', 'puny_code_domain': '', 'ip': '95.211.189.137'}, {'domain': 'www.googloe.com', 'puny_code_domain': '', 'ip': '78.41.204.34'}, {'domain': 'www.goozle.com', 'puny_code_domain': '', 'ip': '50.62.97.1'}, {'domain': 'www.goohle.com', 'puny_code_domain': '', 'ip': '47.254.33.193'}, {'domain': 'www.googl.com', 'puny_code_domain': '', 'ip': '172.217.16.227'}, {'domain': 'www.gooyle.com', 'puny_code_domain': '', 'ip': '66.81.203.201'}, {'domain': 'www.googlde.com', 'puny_code_domain': '', 'ip': '13.248.169.48'}, {'domain': 'www.googlr.com', 'puny_code_domain': '', 'ip': '142.250.187.195'}, {'domain': 'www.gootle.com', 'puny_code_domain': '', 'ip': '66.81.203.201'}, {'domain': 'www.googl4.com', 'puny_code_domain': '', 'ip': '103.224.182.245'}, {'domain': 'www.googli.com', 'puny_code_domain': '', 'ip': '162.255.119.253'}, {'domain': 'www.googlè.com', 'puny_code_domain': 'www.xn--googl-8ra.com', 'ip': '217.160.0.119'}, {'domain': 'www.googlě.com', 'puny_code_domain': 'www.xn--googl-z0a.com', 'ip': '213.186.33.5'}, {'domain': 'www.google4.com', 'puny_code_domain': '', 'ip': '185.53.177.54'}, {'domain': 'www.googlė.com', 'puny_code_domain': 'www.xn--googl-b0a.com', 'ip': '185.53.178.53'}, {'domain': 'www.googlez.com', 'puny_code_domain': '', 'ip': '13.248.169.48'}, {'domain': 'www.googlze.com', 'puny_code_domain': '', 'ip': '75.2.115.196'}, {'domain': 'www.googlé.com', 'puny_code_domain': 'www.xn--googl-fsa.com', 'ip': '69.162.95.6'}, {'domain': 'www.googlz.com', 'puny_code_domain': '', 'ip': '202.31.187.154'}, {'domain': 'www.googleq.com', 'puny_code_domain': '', 'ip': '185.53.178.53'}, {'domain': 'www.googlê.com', 'puny_code_domain': 'www.xn--googl-lsa.com', 'ip': '38.92.48.160'}, {'domain': 'www.googlm.com', 'puny_code_domain': '', 'ip': '204.16.193.4'}, {'domain': 'www.googley.com', 'puny_code_domain': '', 'ip': '85.233.160.215'}, {'domain': 'www.googlet.com', 'puny_code_domain': '', 'ip': '103.224.182.239'}, {'domain': 'www.googlew.com', 'puny_code_domain': '', 'ip': '209.141.38.71'}, {'domain': 'www.googlen.com', 'puny_code_domain': '', 'ip': '103.224.182.239'}, {'domain': 'www.googlee.com', 'puny_code_domain': '', 'ip': '142.250.200.3'}, {'domain': 'www.googleb.com', 'puny_code_domain': '', 'ip': '47.254.33.193'}, {'domain': 'www.googleh.com', 'puny_code_domain': '', 'ip': '75.2.103.221'}, {'domain': 'www.googlem.com', 'puny_code_domain': '', 'ip': '45.58.190.82'}, {'domain': 'www.googel.com', 'puny_code_domain': '', 'ip': '142.250.187.227'}, {'domain': 'www.googlek.com', 'puny_code_domain': '', 'ip': '3.64.163.50'}, {'domain': 'www.googlec.com', 'puny_code_domain': '', 'ip': '3.64.163.50'}, {'domain': 'www.googleg.com', 'puny_code_domain': '', 'ip': '76.223.35.103'}, {'domain': 'www.googlei.com', 'puny_code_domain': '', 'ip': '162.210.199.87'}, {'domain': 'www.googoe.com', 'puny_code_domain': '', 'ip': '66.81.203.11'}, {'domain': 'www.googlle.com', 'puny_code_domain': '', 'ip': '104.21.83.75'}, {'domain': 'www.googlpe.com', 'puny_code_domain': '', 'ip': '103.224.182.207'}, {'domain': 'www.googhe.com', 'puny_code_domain': '', 'ip': '199.59.24 ...

# %%
import copy

domain_data = copy.deepcopy(output['data'])
domain_data
# Out:
# [{'domain': 'www.google.org', 'puny_code_domain': '', 'ip': '216.239.32.27'},
#  {'domain': 'ww.google.com', 'puny_code_domain': '', 'ip': '142.250.200.46'},
#  {'domain': 'www.google.co', 'puny_code_domain': '', 'ip': '142.250.187.206'},
#  {'domain': 'www.google.net', 'puny_code_domain': '', 'ip': '142.250.200.36'},
#  {'domain': 'www.google.de', 'puny_code_domain': '', 'ip': '172.217.16.227'},
#  {'domain': 'www.google.tk', 'puny_code_domain': '', 'ip': '142.250.200.3'},
#  {'domain': 'wwwngoogle.com', 'puny_code_domain': '', 'ip': '199.59.243.225'},
#  {'domain': 'wwwgoogle.com', 'puny_code_domain': '', 'ip': '216.58.212.228'},
#  {'domain': 'www.go0ogle.com', 'puny_code_domain': '', 'ip': '95.211.189.138'},
#  {'domain': 'www.gookgle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.226'},
#  {'domain': 'wwwg.oogle.com', 'puny_code_domain': '', 'ip': '104.21.19.57'},
#  {'domain': 'www.googlwe.com', 'puny_code_domain': '', 'ip': '95.211.189.137'},
#  {'domain': 'www.googloe.com', 'puny_code_domain': '', 'ip': '78.41.204.34'},
#  {'domain': 'www.goozle.com', 'puny_code_domain': '', 'ip': '50.62.97.1'},
#  {'domain': 'www.goohle.com', 'puny_code_domain': '', 'ip': '47.254.33.193'},
#  {'domain': 'www.googl.com', 'puny_code_domain': '', 'ip': '172.217.16.227'},
#  {'domain': 'www.gooyle.com', 'puny_code_domain': '', 'ip': '66.81.203.201'},
#  {'domain': 'www.googlde.com', 'puny_code_domain': '', 'ip': '13.248.169.48'},
#  {'domain': 'www.googlr.com', 'puny_code_domain': '', 'ip': '142.250.187.195'},
#  {'domain': 'www.gootle.com', 'puny_code_domain': '', 'ip': '66.81.203.201'},
#  {'domain': 'www.googl4.com', 'puny_code_domain': '', 'ip': '103.224.182.245'},
#  {'domain': 'www.googli.com', 'puny_code_domain': '', 'ip': '162.255.119.253'},
#  {'domain': 'www.googlè.com',
#   'puny_code_domain': 'www.xn--googl-8ra.com',
#   'ip': '217.160.0.119'},
#  {'domain': 'www.googlě.com',
#   'puny_code_domain': 'www.xn--googl-z0a.com',
#   'ip': '213.186.33.5'},
#  {'domain': 'www.google4.com', 'puny_code_domain': '', 'ip': '185.53.177.54'},
#  {'domain': 'www.googlė.com',
#   'puny_code_domain': 'www.xn--googl-b0a.com',
#   'ip': '185.53.178.53'},
#  {'domain': 'www.googlez.com', 'puny_code_domain': '', 'ip': '13.248.169.48'},
#  {'domain': 'www.googlze.com', 'puny_code_domain': '', 'ip': '75.2.115.196'},
#  {'domain': 'www.googlé.com',
#   'puny_code_domain': 'www.xn--googl-fsa.com',
#   'ip': '69.162.95.6'},
#  {'domain': 'www.googlz.com', 'puny_code_domain': '', 'ip': '202.31.187.154'},
#  {'domain': 'www.googleq.com', 'puny_code_domain': '', 'ip': '185.53.178.53'},
#  {'domain': 'www.googlê.com',
#   'puny_code_domain': 'www.xn--googl-lsa.com',
#   'ip': '38.92.48.160'},
#  {'domain': 'www.googlm.com', 'puny_code_domain': '', 'ip': '204.16.193.4'},
#  {'domain': 'www.googley.com', 'puny_code_domain': '', 'ip': '85.233.160.215'},
#  {'domain': 'www.googlet.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.239'},
#  {'domain': 'www.googlew.com', 'puny_code_domain': '', 'ip': '209.141.38.71'},
#  {'domain': 'www.googlen.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.239'},
#  {'domain': 'www.googlee.com', 'puny_code_domain': '', 'ip': '142.250.200.3'},
#  {'domain': 'www.googleb.com', 'puny_code_domain': '', 'ip': '47.254.33.193'},
#  {'domain': 'www.googleh.com', 'puny_code_domain': '', 'ip': '75.2.103.221'},
#  {'domain': 'www.googlem.com', 'puny_code_domain': '', 'ip': '45.58.190.82'},
#  {'domain': 'www.googel.com', 'puny_code_domain': '', 'ip': '142.250.187.227'},
#  {'domain': 'www.googlek.com', 'puny_code_domain': '', 'ip': '3.64.163.50'},
#  {'domain': 'www.googlec.com', 'puny_code_domain': '', 'ip': '3.64.163.50'},
#  {'domain': 'www.googleg.com', 'puny_code_domain': '', 'ip': '76.223.35.103'},
#  {'domain': 'www.googlei.com', 'puny_code_domain': '', 'ip': '162.210.199.87'},
#  {'domain': 'www.googoe.com', 'puny_code_domain': '', 'ip': '66.81.203.11'},
#  {'domain': 'www.googlle.com', 'puny_code_domain': '', 'ip': '104.21.83.75'},
#  {'domain': 'www.googlpe.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.207'},
#  {'domain': 'www.googhe.com', 'puny_code_domain': '', 'ip': '199.59.243.225'},
#  {'domain': 'www.googlme.com',
#   'puny_code_domain': '',
#   'ip': '116.202.118.107'},
#  {'domain': 'www.googple.com',
#   'puny_code_domain': '',
#   'ip': '103.224.212.210'},
#  {'domain': 'www.googmle.com', 'puny_code_domain': '', 'ip': '64.91.248.15'},
#  {'domain': 'www.googme.com', 'puny_code_domain': '', 'ip': '199.59.243.225'},
#  {'domain': 'www.googlke.com', 'puny_code_domain': '', 'ip': '64.32.22.102'},
#  {'domain': 'www.goo.gle.com', 'puny_code_domain': '', 'ip': '13.248.169.48'},
#  {'domain': 'www.goog-le.com', 'puny_code_domain': '', 'ip': '74.208.236.69'},
#  {'domain': 'www.googe.com', 'puny_code_domain': '', 'ip': '162.243.10.151'},
#  {'domain': 'www.googłe.com',
#   'puny_code_domain': 'www.xn--googe-n7a.com',
#   'ip': '46.4.60.204'},
#  {'domain': 'www.goolge.com', 'puny_code_domain': '', 'ip': '216.58.212.227'},
#  {'domain': 'www.googvle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.207'},
#  {'domain': 'www.goole.com', 'puny_code_domain': '', 'ip': '217.160.0.201'},
#  {'domain': 'www.goovle.com', 'puny_code_domain': '', 'ip': '162.210.199.65'},
#  {'domain': 'www.goofgle.com', 'puny_code_domain': '', 'ip': '185.53.178.50'},
#  {'domain': 'www.googfle.com', 'puny_code_domain': '', 'ip': '185.53.177.53'},
#  {'domain': 'www.googie.com', 'puny_code_domain': '', 'ip': '209.17.116.160'},
#  {'domain': 'www.goobgle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.238'},
#  {'domain': 'www.gooble.com', 'puny_code_domain': '', 'ip': '64.190.63.222'},
#  {'domain': 'www.goofle.com', 'puny_code_domain': '', 'ip': '162.210.199.65'},
#  {'domain': 'www.gooǥle.com',
#   'puny_code_domain': 'www.xn--goole-k0b.com',
#   'ip': '216.58.201.110'},
#  {'domain': 'www.googble.com', 'puny_code_domain': '', 'ip': '72.52.178.23'},
#  {'domain': 'www.goohgle.com', 'puny_code_domain': '', 'ip': '104.252.32.152'},
#  {'domain': 'www.go9gle.com', 'puny_code_domain': '', 'ip': '64.190.63.222'},
#  {'domain': 'www.goowle.com', 'puny_code_domain': '', 'ip': '185.107.56.199'},
#  {'domain': 'www.googyle.com', 'puny_code_domain': '', 'ip': '93.115.28.104'},
#  {'domain': 'www.goegle.com', 'puny_code_domain': '', 'ip': '103.224.182.246'},
#  {'domain': 'www.googzle.com', 'puny_code_domain': '', 'ip': '52.66.233.38'},
#  {'domain': 'www.gogole.com', 'puny_code_domain': '', 'ip': '216.58.204.67'},
#  {'domain': 'www.guogle.com', 'puny_code_domain': '', 'ip': '64.190.63.222'},
#  {'domain': 'www.g.oogle.com', 'puny_code_domain': '', 'ip': '104.21.19.57'},
#  {'domain': 'www.goagle.com', 'puny_code_domain': '', 'ip': '89.145.66.234'},
#  {'domain': 'www.goopgle.com', 'puny_code_domain': '', 'ip': '95.211.219.66'},
#  {'domain': 'www.glogle.com', 'puny_code_domain': '', 'ip': '66.81.203.11'},
#  {'domain': 'www.gogle.com', 'puny_code_domain': '', 'ip': '142.250.200.3'},
#  {'domain': 'www.g9ogle.com', 'puny_code_domain': '', 'ip': '103.224.182.238'},
#  {'domain': 'www.geogle.com', 'puny_code_domain': '', 'ip': '78.41.204.38'},
#  {'domain': 'www.goọgle.com',
#   'puny_code_domain': 'www.xn--gogle-381b.com',
#   'ip': '217.70.184.50'},
#  {'domain': 'www.gokogle.com', 'puny_code_domain': '', 'ip': '185.53.178.50'},
#  {'domain': 'www.gkoogle.com', 'puny_code_domain': '', 'ip': '13.248.169.48'},
#  {'domain': 'www.gpogle.com', 'puny_code_domain': '', 'ip': '69.162.95.4'},
#  {'domain': 'www.go-ogle.com', 'puny_code_domain': '', 'ip': '66.96.149.22'},
#  {'domain': 'www.gaogle.com', 'puny_code_domain': '', 'ip': '107.180.51.12'},
#  {'domain': 'www.gioogle.com', 'puny_code_domain': '', 'ip': '185.53.178.51'},
#  {'domain': 'www.gooogle.com', 'puny_code_domain': '', 'ip': '172.217.169.67'},
#  {'domain': 'www.go9ogle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.250'},
#  {'domain': 'www.boogle.com', 'puny_code_domain': '', 'ip': '13.248.169.48'},
#  {'domain': 'www.voogle.com', 'puny_code_domain': '', 'ip': '3.64.163.50'},
#  {'domain': 'www.ogogle.com', 'puny_code_domain': '', 'ip': '142.250.200.35'},
#  {'domain': 'www.g0ogle.com', 'puny_code_domain': '', 'ip': '64.91.249.20'},
#  {'domain': 'www.gpoogle.com', 'puny_code_domain': '', 'ip': '104.143.9.110'},
#  {'domain': 'www.gopogle.com', 'puny_code_domain': '', 'ip': '173.44.37.208'},
#  {'domain': 'www.oogle.com', 'puny_code_domain': '', 'ip': '104.21.19.57'},
#  {'domain': 'www.g9oogle.com', 'puny_code_domain': '', 'ip': '52.33.207.7'},
#  {'domain': 'www.gvoogle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.246'},
#  {'domain': 'www.göogle.com',
#   'puny_code_domain': 'www.xn--gogle-jua.com',
#   'ip': '3.33.130.190'},
#  {'domain': 'www.vgoogle.com', 'puny_code_domain': '', 'ip': '47.254.33.193'},
#  {'domain': 'www.ggoogle.com', 'puny_code_domain': '', 'ip': '142.250.178.3'},
#  {'domain': 'www.toogle.com', 'puny_code_domain': '', 'ip': '3.33.130.190'},
#  {'domain': 'www.gọogle.com',
#   'puny_code_domain': 'www.xn--gogle-281b.com',
#   'ip': '99.83.176.46'},
#  {'domain': 'www.gyoogle.com', 'puny_code_domain': '', 'ip': '199.59.243.225'},
#  {'domain': 'www.hgoogle.com', 'puny_code_domain': '', 'ip': '173.44.37.208'},
#  {'domain': 'www.bgoogle.com', 'puny_code_domain': '', 'ip': '45.58.190.82'},
#  {'domain': 'www.gboogle.com', 'puny_code_domain': '', 'ip': '185.107.56.202'},
#  {'domain': 'www.zoogle.com', 'puny_code_domain': '', 'ip': '192.254.233.61'},
#  {'domain': 'www.yoogle.com', 'puny_code_domain': '', 'ip': '127.0.0.1'},
#  {'domain': 'www.tgoogle.com', 'puny_code_domain': '', 'ip': '198.251.81.30'},
#  {'domain': 'www.fgoogle.com', 'puny_code_domain': '', 'ip': '127.0.0.10'},
#  {'domain': 'www.google.in', 'puny_code_domain': '', 'ip': '216.58.204.67'},
#  {'domain': 'www.google.ru', 'puny_code_domain': '', 'ip': '142.250.178.3'},
#  {'domain': 'www.ĝoogle.com',
#   'puny_code_domain': 'www.xn--oogle-60a.com',
#   'ip': '64.225.91.73'},
#  {'domain': 'www.google.ml', 'puny_code_domain': '', 'ip': '142.250.187.227'},
#  {'domain': 'www.foogle.com', 'puny_code_domain': '', 'ip': '173.236.255.36'},
#  {'domain': 'www.google.io', 'puny_code_domain': '', 'ip': '142.250.180.3'},
#  {'domain': 'www.google.cf', 'puny_code_domain': '', 'ip': '142.250.200.3'},
#  {'domain': 'www.woogle.com', 'puny_code_domain': '', 'ip': '64.98.135.11'},
#  {'domain': 'www.googlecom.com',
#   'puny_code_domain': '',
#   'ip': '172.217.16.227'},
#  {'domain': 'account-verify-google.com',
#   'puny_code_domain': '',
#   'ip': '65.108.50.121'},
#  {'domain': 'www.google.ga', 'puny_code_domain': '', 'ip': '216.58.212.195'},
#  {'domain': 'www.google.com', 'puny_code_domain': '', 'ip': '142.250.200.36'},
#  {'domain': 'login-google.com', 'puny_code_domain': '', 'ip': '20.42.95.243'},
#  {'domain': 'www.google.cn', 'puny_code_domain': '', 'ip': '216.58.201.99'},
#  {'domain': 'www.google.info',
#   'puny_code_domain': '',
#   'ip': '142.250.179.227'},
#  {'domain': 'auth-google.com',
#   'puny_code_domain': '',
#   'ip': '128.199.247.177'},
#  {'domain': 'security-google.com',
#   'puny_code_domain': '',
#   'ip': '142.250.180.14'}]

# %% [markdown]
# # Code for REST API for fetching domain registration date and country using Flask and whois cli
#
# ## Note: Using available trial API's from internet is creating some issues in terms of data format consistency and query limits,  so I have created a rest api by making use of whois cli to query the registration date and the country. For the next Async and Sync API call codes, domain registration date and country are extracted using this API. This API is running in an Azure Windows 11 VM.

# %%
from flask import Flask
import subprocess
import re
import idna

app = Flask(__name__)

@app.get('/get_domain_details/<domain>')
def get_domain_details(domain):
    creation_date = ""
    registrant_country = ""
    command = f"whois {domain}"
    process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    output,error = process.communicate()
    output_str = output.decode("utf-8")
    creation_date_pattern = r"Creation Date: (\d{4}-\d{2}-\d{2})"
    registrant_country_pattern = r"Registrant Country: (\w+)"
    creation_date_match = re.search(creation_date_pattern, output_str)
    if creation_date_match:
        creation_date = creation_date_match.group(1)
    registrant_country_match = re.search(registrant_country_pattern, output_str)
    if registrant_country_match:
        registrant_country = registrant_country_match.group(1)
    return {"domain":idna.decode(domain), "reg_date":creation_date, "country":registrant_country}

if __name__ == "__main__":
    app.run(host="0.0.0.0", port=8000, debug=True)

# %% [markdown]
# # Code to get the Domain Registration Date and Country through Async API calls
#
# ## Note: Due to some limitation of jupyter notebook, Async API calls are very difficult to implement. But the same code will work standalone. Synchronous API call code is also attached below this code which is used for the time being to get the data.

# %%
"""
    Module to get the Domain registration date 
    and country using Asynchronous API call

"""

import aiohttp
import asyncio

API_ENDPOINT = "http://20.67.244.20:8000"

class AsyncAPICall:
    """
        This class does Asynchronous API Calls and returns 
        the response of all the requests in a list
        
        Attribute:
        domain_list: list
                    all typesquated scraped domain data
        
    """
    
    def __init__(self, domain_list: list):
        self.domain_list = domain_list

    async def fetch_domain_data(self, session, url: str):
        """
            This method uses session.get() to make an asynchronous HTTP GET request
            and returns the API response in json format
        
        """
        async with session.get(url) as response:
            return await response.json()

    async def main(self) -> list:
        """
            This method is the main function which creates ClientSession for 
            making asynchronous HTTP requests
            
            'asyncio.gather()' runs the tasks concurrently and gather their results
        
        """
        results = []
        async with aiohttp.ClientSession() as session:
            url = f"{API_ENDPOINT}/get_domain_details"
            tasks = [self.fetch_domain_data(session, f"{url}/{domain['domain']}") for domain in self.domain_list]
            results = await asyncio.gather(*tasks)
        return results
    
    def merge_domain_details(self, data_async: list) -> list:
        """
            This function merges the async api output list 
            with the input domain list

        Args:
            data_async (list): async api output

        Returns:
            list: merged input list of domain dict with the 
            l     location and registartion date
        """
        new_dict = {x['domain']: x for x in self.domain_list}
        for item in data_async:
            if item['domain'] in new_dict:
                new_dict[item['domain']].update(item)
            else:
                new_dict[item['domain']] = item
        merged_list = list(new_dict.values())
        return merged_list

if __name__ == "__main__":
    async_obj = AsyncAPICall(domain_data)
    data = asyncio.run(async_obj.main())
    final_output = async_obj.merge_domain_details(data)
    print(final_output)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[234], line 73
#      71 if __name__ == "__main__":
#      72     async_obj = AsyncAPICall(domain_data)
# ---> 73     data = asyncio.run(async_obj.main())
#      74     final_output = async_obj.merge_domain_details(data)
#      75     print(final_output)
#
# File C:\ProgramData\anaconda3\Lib\asyncio\runners.py:186, in run(main, debug)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)
#     182     asyncio.run(main())
#     183 """
#     184 if events._get_running_loop() is not None:
#     185     # fail fast with short traceback
# --> 186     raise RuntimeError(
#     187         "asyncio.run() cannot be called from a running event loop")
#     189 with Runner(debug=debug) as runner:
#     190     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %% [markdown]
# # Code to get the Domain Registration Date and Country through Synchronous API calls

# %%
"""
    Module to get the Domain registration date 
    and country using Synchronous API call

"""

import requests

API_ENDPOINT = "http://20.67.244.20:8000"

class APICall:
    """
     This class does Sync API calls to get 
     domain registration date and country
     through rest api
     
     Attribute:
        domain_list: list
                    all typesquated scraped domain data
    
    """
    def __init__(self, domain_list: list):
        self.domain_list = domain_list
    
    def get_api_call(self, domain_name: str) -> tuple:
        """
            This method do get API call with three retries 
            if there is any error from API end and returns the data
        
        """
        base_url = f"{API_ENDPOINT}/get_domain_details"
        url = f"{base_url}/{domain_name}"
        retry = 3
        response = ""
        while retry > 0:
            response = requests.get(url=url, timeout=60)
            if response.status_code == 200:
                return True, response.json()
            else:
                retry = retry - 1
                time.sleep(5)
        return False, str(response.content)         
        
    def main(self) -> tuple:
        """
            This is the main method
        
        """
        for domain in self.domain_list:
            domain_name = domain["domain"]
            if domain['puny_code_domain'] != "":
                domain_name = domain['puny_code_domain']
            status, d_data = self.get_api_call(domain_name)
            if status:
                domain.update(d_data)
            else:
                return False, f"Failed to get data from API. Error: {d_data}"
        return True, self.domain_list
    
if __name__ == "__main__":
    status, out = APICall(domain_data).main()  
    print(out)
# Out:
# [{'domain': 'www.google.org', 'puny_code_domain': '', 'ip': '216.239.32.27', 'country': 'US', 'reg_date': '1998-10-21'}, {'domain': 'ww.google.com', 'puny_code_domain': '', 'ip': '142.250.200.46', 'country': 'US', 'reg_date': '1997-09-15'}, {'domain': 'www.google.co', 'puny_code_domain': '', 'ip': '142.250.187.206', 'country': '', 'reg_date': ''}, {'domain': 'www.google.net', 'puny_code_domain': '', 'ip': '142.250.200.36', 'country': 'US', 'reg_date': '1999-03-15'}, {'domain': 'www.google.de', 'puny_code_domain': '', 'ip': '172.217.16.227', 'country': '', 'reg_date': ''}, {'domain': 'www.google.tk', 'puny_code_domain': '', 'ip': '142.250.200.3', 'country': '', 'reg_date': ''}, {'domain': 'wwwngoogle.com', 'puny_code_domain': '', 'ip': '199.59.243.225', 'country': '', 'reg_date': '2011-05-16'}, {'domain': 'wwwgoogle.com', 'puny_code_domain': '', 'ip': '216.58.212.228', 'country': 'US', 'reg_date': '1999-03-03'}, {'domain': 'www.go0ogle.com', 'puny_code_domain': '', 'ip': '95.211.189.138', 'country': 'PA', 'reg_date': '2002-09-01'}, {'domain': 'www.gookgle.com', 'puny_code_domain': '', 'ip': '103.224.182.226', 'country': '', 'reg_date': '2008-07-21'}, {'domain': 'wwwg.oogle.com', 'puny_code_domain': '', 'ip': '104.21.19.57', 'country': 'IS', 'reg_date': '1999-02-07'}, {'domain': 'www.googlwe.com', 'puny_code_domain': '', 'ip': '95.211.189.137', 'country': 'US', 'reg_date': '2000-11-13'}, {'domain': 'www.googloe.com', 'puny_code_domain': '', 'ip': '78.41.204.34', 'country': 'US', 'reg_date': '2000-11-09'}, {'domain': 'www.goozle.com', 'puny_code_domain': '', 'ip': '50.62.97.1', 'country': 'US', 'reg_date': '1999-10-04'}, {'domain': 'www.goohle.com', 'puny_code_domain': '', 'ip': '47.254.33.193', 'country': 'CN', 'reg_date': '2002-06-03'}, {'domain': 'www.googl.com', 'puny_code_domain': '', 'ip': '172.217.16.227', 'country': 'US', 'reg_date': '2001-01-24'}, {'domain': 'www.gooyle.com', 'puny_code_domain': '', 'ip': '66.81.203.201', 'country': 'US', 'reg_date': '2000-10-02'}, {'domain': 'www.googlde.com', 'puny_code_domain': '', 'ip': '13.248.169.48', 'country': '', 'reg_date': '2002-12-01'}, {'domain': 'www.googlr.com', 'puny_code_domain': '', 'ip': '142.250.187.195', 'country': 'US', 'reg_date': '2001-05-29'}, {'domain': 'www.gootle.com', 'puny_code_domain': '', 'ip': '66.81.203.201', 'country': 'US', 'reg_date': '2000-10-02'}, {'domain': 'www.googl4.com', 'puny_code_domain': '', 'ip': '103.224.182.245', 'country': '', 'reg_date': '2007-10-04'}, {'domain': 'www.googli.com', 'puny_code_domain': '', 'ip': '162.255.119.253', 'country': 'CN', 'reg_date': '2012-09-04'}, {'domain': 'www.googlè.com', 'puny_code_domain': 'www.xn--googl-8ra.com', 'ip': '217.160.0.119', 'country': 'FR', 'reg_date': '2023-12-21'}, {'domain': 'www.googlě.com', 'puny_code_domain': 'www.xn--googl-z0a.com', 'ip': '213.186.33.5', 'country': 'FR', 'reg_date': '2022-01-14'}, {'domain': 'www.google4.com', 'puny_code_domain': '', 'ip': '185.53.177.54', 'country': '', 'reg_date': '2004-06-11'}, {'domain': 'www.googlė.com', 'puny_code_domain': 'www.xn--googl-b0a.com', 'ip': '185.53.178.53', 'country': 'US', 'reg_date': '2015-11-05'}, {'domain': 'www.googlez.com', 'puny_code_domain': '', 'ip': '13.248.169.48', 'country': '', 'reg_date': '2023-04-26'}, {'domain': 'www.googlze.com', 'puny_code_domain': '', 'ip': '75.2.115.196', 'country': '', 'reg_date': '2010-11-18'}, {'domain': 'www.googlé.com', 'puny_code_domain': 'www.xn--googl-fsa.com', 'ip': '69.162.95.6', 'country': '', 'reg_date': '2011-10-06'}, {'domain': 'www.googlz.com', 'puny_code_domain': '', 'ip': '202.31.187.154', 'country': 'KR', 'reg_date': '2005-03-18'}, {'domain': 'www.googleq.com', 'puny_code_domain': '', 'ip': '185.53.178.53', 'country': 'US', 'reg_date': '2020-09-01'}, {'domain': 'www.googlê.com', 'puny_code_domain': 'www.xn--googl-lsa.com', 'ip': '38.92.48.160', 'country': 'IS', 'reg_date': '2024-03-13'}, {'domain': 'www.googlm.com', 'puny_code_domain': '', 'ip': '204.16.193.4', 'country': '', 'reg ...

# %% [markdown]
# # Observation:
# ## Execution time of Async API call was aprox. 9 to 10 times faster than the Sync API call

# %%
new_output = copy.deepcopy(out)
new_output
# Out:
# [{'domain': 'www.google.org',
#   'puny_code_domain': '',
#   'ip': '216.239.32.27',
#   'country': 'US',
#   'reg_date': '1998-10-21'},
#  {'domain': 'ww.google.com',
#   'puny_code_domain': '',
#   'ip': '142.250.200.46',
#   'country': 'US',
#   'reg_date': '1997-09-15'},
#  {'domain': 'www.google.co',
#   'puny_code_domain': '',
#   'ip': '142.250.187.206',
#   'country': '',
#   'reg_date': ''},
#  {'domain': 'www.google.net',
#   'puny_code_domain': '',
#   'ip': '142.250.200.36',
#   'country': 'US',
#   'reg_date': '1999-03-15'},
#  {'domain': 'www.google.de',
#   'puny_code_domain': '',
#   'ip': '172.217.16.227',
#   'country': '',
#   'reg_date': ''},
#  {'domain': 'www.google.tk',
#   'puny_code_domain': '',
#   'ip': '142.250.200.3',
#   'country': '',
#   'reg_date': ''},
#  {'domain': 'wwwngoogle.com',
#   'puny_code_domain': '',
#   'ip': '199.59.243.225',
#   'country': '',
#   'reg_date': '2011-05-16'},
#  {'domain': 'wwwgoogle.com',
#   'puny_code_domain': '',
#   'ip': '216.58.212.228',
#   'country': 'US',
#   'reg_date': '1999-03-03'},
#  {'domain': 'www.go0ogle.com',
#   'puny_code_domain': '',
#   'ip': '95.211.189.138',
#   'country': 'PA',
#   'reg_date': '2002-09-01'},
#  {'domain': 'www.gookgle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.226',
#   'country': '',
#   'reg_date': '2008-07-21'},
#  {'domain': 'wwwg.oogle.com',
#   'puny_code_domain': '',
#   'ip': '104.21.19.57',
#   'country': 'IS',
#   'reg_date': '1999-02-07'},
#  {'domain': 'www.googlwe.com',
#   'puny_code_domain': '',
#   'ip': '95.211.189.137',
#   'country': 'US',
#   'reg_date': '2000-11-13'},
#  {'domain': 'www.googloe.com',
#   'puny_code_domain': '',
#   'ip': '78.41.204.34',
#   'country': 'US',
#   'reg_date': '2000-11-09'},
#  {'domain': 'www.goozle.com',
#   'puny_code_domain': '',
#   'ip': '50.62.97.1',
#   'country': 'US',
#   'reg_date': '1999-10-04'},
#  {'domain': 'www.goohle.com',
#   'puny_code_domain': '',
#   'ip': '47.254.33.193',
#   'country': 'CN',
#   'reg_date': '2002-06-03'},
#  {'domain': 'www.googl.com',
#   'puny_code_domain': '',
#   'ip': '172.217.16.227',
#   'country': 'US',
#   'reg_date': '2001-01-24'},
#  {'domain': 'www.gooyle.com',
#   'puny_code_domain': '',
#   'ip': '66.81.203.201',
#   'country': 'US',
#   'reg_date': '2000-10-02'},
#  {'domain': 'www.googlde.com',
#   'puny_code_domain': '',
#   'ip': '13.248.169.48',
#   'country': '',
#   'reg_date': '2002-12-01'},
#  {'domain': 'www.googlr.com',
#   'puny_code_domain': '',
#   'ip': '142.250.187.195',
#   'country': 'US',
#   'reg_date': '2001-05-29'},
#  {'domain': 'www.gootle.com',
#   'puny_code_domain': '',
#   'ip': '66.81.203.201',
#   'country': 'US',
#   'reg_date': '2000-10-02'},
#  {'domain': 'www.googl4.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.245',
#   'country': '',
#   'reg_date': '2007-10-04'},
#  {'domain': 'www.googli.com',
#   'puny_code_domain': '',
#   'ip': '162.255.119.253',
#   'country': 'CN',
#   'reg_date': '2012-09-04'},
#  {'domain': 'www.googlè.com',
#   'puny_code_domain': 'www.xn--googl-8ra.com',
#   'ip': '217.160.0.119',
#   'country': 'FR',
#   'reg_date': '2023-12-21'},
#  {'domain': 'www.googlě.com',
#   'puny_code_domain': 'www.xn--googl-z0a.com',
#   'ip': '213.186.33.5',
#   'country': 'FR',
#   'reg_date': '2022-01-14'},
#  {'domain': 'www.google4.com',
#   'puny_code_domain': '',
#   'ip': '185.53.177.54',
#   'country': '',
#   'reg_date': '2004-06-11'},
#  {'domain': 'www.googlė.com',
#   'puny_code_domain': 'www.xn--googl-b0a.com',
#   'ip': '185.53.178.53',
#   'country': 'US',
#   'reg_date': '2015-11-05'},
#  {'domain': 'www.googlez.com',
#   'puny_code_domain': '',
#   'ip': '13.248.169.48',
#   'country': '',
#   'reg_date': '2023-04-26'},
#  {'domain': 'www.googlze.com',
#   'puny_code_domain': '',
#   'ip': '75.2.115.196',
#   'country': '',
#   'reg_date': '2010-11-18'},
#  {'domain': 'www.googlé.com',
#   'puny_code_domain': 'www.xn--googl-fsa.com',
#   'ip': '69.162.95.6',
#   'country': '',
#   'reg_date': '2011-10-06'},
#  {'domain': 'www.googlz.com',
#   'puny_code_domain': '',
#   'ip': '202.31.187.154',
#   'country': 'KR',
#   'reg_date': '2005-03-18'},
#  {'domain': 'www.googleq.com',
#   'puny_code_domain': '',
#   'ip': '185.53.178.53',
#   'country': 'US',
#   'reg_date': '2020-09-01'},
#  {'domain': 'www.googlê.com',
#   'puny_code_domain': 'www.xn--googl-lsa.com',
#   'ip': '38.92.48.160',
#   'country': 'IS',
#   'reg_date': '2024-03-13'},
#  {'domain': 'www.googlm.com',
#   'puny_code_domain': '',
#   'ip': '204.16.193.4',
#   'country': '',
#   'reg_date': '2003-12-18'},
#  {'domain': 'www.googley.com',
#   'puny_code_domain': '',
#   'ip': '85.233.160.215',
#   'country': 'GB',
#   'reg_date': '1999-10-19'},
#  {'domain': 'www.googlet.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.239',
#   'country': 'US',
#   'reg_date': '2005-08-21'},
#  {'domain': 'www.googlew.com',
#   'puny_code_domain': '',
#   'ip': '209.141.38.71',
#   'country': 'US',
#   'reg_date': '2001-10-20'},
#  {'domain': 'www.googlen.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.239',
#   'country': 'US',
#   'reg_date': '2005-08-21'},
#  {'domain': 'www.googlee.com',
#   'puny_code_domain': '',
#   'ip': '142.250.200.3',
#   'country': 'US',
#   'reg_date': '2000-04-06'},
#  {'domain': 'www.googleb.com',
#   'puny_code_domain': '',
#   'ip': '47.254.33.193',
#   'country': 'CN',
#   'reg_date': '2010-12-28'},
#  {'domain': 'www.googleh.com',
#   'puny_code_domain': '',
#   'ip': '75.2.103.221',
#   'country': 'IM',
#   'reg_date': '2023-12-20'},
#  {'domain': 'www.googlem.com',
#   'puny_code_domain': '',
#   'ip': '45.58.190.82',
#   'country': 'US',
#   'reg_date': '2000-11-20'},
#  {'domain': 'www.googel.com',
#   'puny_code_domain': '',
#   'ip': '142.250.187.227',
#   'country': 'US',
#   'reg_date': '2001-01-24'},
#  {'domain': 'www.googlek.com',
#   'puny_code_domain': '',
#   'ip': '3.64.163.50',
#   'country': '',
#   'reg_date': '2020-08-25'},
#  {'domain': 'www.googlec.com',
#   'puny_code_domain': '',
#   'ip': '3.64.163.50',
#   'country': 'US',
#   'reg_date': '2001-02-17'},
#  {'domain': 'www.googleg.com',
#   'puny_code_domain': '',
#   'ip': '76.223.35.103',
#   'country': 'US',
#   'reg_date': '2024-01-09'},
#  {'domain': 'www.googlei.com',
#   'puny_code_domain': '',
#   'ip': '162.210.199.87',
#   'country': 'US',
#   'reg_date': '2003-01-17'},
#  {'domain': 'www.googoe.com',
#   'puny_code_domain': '',
#   'ip': '66.81.203.11',
#   'country': 'US',
#   'reg_date': '2000-10-02'},
#  {'domain': 'www.googlle.com',
#   'puny_code_domain': '',
#   'ip': '104.21.83.75',
#   'country': '',
#   'reg_date': '2000-06-29'},
#  {'domain': 'www.googlpe.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.207',
#   'country': '',
#   'reg_date': '2003-08-24'},
#  {'domain': 'www.googhe.com',
#   'puny_code_domain': '',
#   'ip': '199.59.243.225',
#   'country': 'US',
#   'reg_date': '2002-08-08'},
#  {'domain': 'www.googlme.com',
#   'puny_code_domain': '',
#   'ip': '116.202.118.107',
#   'country': 'US',
#   'reg_date': '2005-04-27'},
#  {'domain': 'www.googple.com',
#   'puny_code_domain': '',
#   'ip': '103.224.212.210',
#   'country': 'US',
#   'reg_date': '2023-07-29'},
#  {'domain': 'www.googmle.com',
#   'puny_code_domain': '',
#   'ip': '64.91.248.15',
#   'country': 'US',
#   'reg_date': '2004-02-22'},
#  {'domain': 'www.googme.com',
#   'puny_code_domain': '',
#   'ip': '199.59.243.225',
#   'country': 'US',
#   'reg_date': '2002-08-08'},
#  {'domain': 'www.googlke.com',
#   'puny_code_domain': '',
#   'ip': '64.32.22.102',
#   'country': '',
#   'reg_date': '2000-11-13'},
#  {'domain': 'www.goo.gle.com',
#   'puny_code_domain': '',
#   'ip': '13.248.169.48',
#   'country': 'US',
#   'reg_date': '2001-12-29'},
#  {'domain': 'www.goog-le.com',
#   'puny_code_domain': '',
#   'ip': '74.208.236.69',
#   'country': 'US',
#   'reg_date': '2004-11-24'},
#  {'domain': 'www.googe.com',
#   'puny_code_domain': '',
#   'ip': '162.243.10.151',
#   'country': 'US',
#   'reg_date': '1998-10-02'},
#  {'domain': 'www.googłe.com',
#   'puny_code_domain': 'www.xn--googe-n7a.com',
#   'ip': '46.4.60.204',
#   'country': 'TR',
#   'reg_date': '2016-02-03'},
#  {'domain': 'www.goolge.com',
#   'puny_code_domain': '',
#   'ip': '216.58.212.227',
#   'country': 'US',
#   'reg_date': '1999-06-04'},
#  {'domain': 'www.googvle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.207',
#   'country': '',
#   'reg_date': '2003-08-24'},
#  {'domain': 'www.goole.com',
#   'puny_code_domain': '',
#   'ip': '217.160.0.201',
#   'country': 'GB',
#   'reg_date': '1999-11-09'},
#  {'domain': 'www.goovle.com',
#   'puny_code_domain': '',
#   'ip': '162.210.199.65',
#   'country': 'BS',
#   'reg_date': '2017-09-23'},
#  {'domain': 'www.goofgle.com',
#   'puny_code_domain': '',
#   'ip': '185.53.178.50',
#   'country': '',
#   'reg_date': '2004-09-23'},
#  {'domain': 'www.googfle.com',
#   'puny_code_domain': '',
#   'ip': '185.53.177.53',
#   'country': 'US',
#   'reg_date': '2008-11-13'},
#  {'domain': 'www.googie.com',
#   'puny_code_domain': '',
#   'ip': '209.17.116.160',
#   'country': 'US',
#   'reg_date': '1998-01-21'},
#  {'domain': 'www.goobgle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.238',
#   'country': '',
#   'reg_date': '2011-12-07'},
#  {'domain': 'www.gooble.com',
#   'puny_code_domain': '',
#   'ip': '64.190.63.222',
#   'country': 'IS',
#   'reg_date': '1999-07-27'},
#  {'domain': 'www.goofle.com',
#   'puny_code_domain': '',
#   'ip': '162.210.199.65',
#   'country': '',
#   'reg_date': '1999-07-30'},
#  {'domain': 'www.gooǥle.com',
#   'puny_code_domain': 'www.xn--goole-k0b.com',
#   'ip': '216.58.201.110',
#   'country': 'US',
#   'reg_date': '2017-03-23'},
#  {'domain': 'www.googble.com',
#   'puny_code_domain': '',
#   'ip': '72.52.178.23',
#   'country': 'TH',
#   'reg_date': '2002-02-19'},
#  {'domain': 'www.goohgle.com',
#   'puny_code_domain': '',
#   'ip': '104.252.32.152',
#   'country': '',
#   'reg_date': '2023-11-03'},
#  {'domain': 'www.go9gle.com',
#   'puny_code_domain': '',
#   'ip': '64.190.63.222',
#   'country': 'GE',
#   'reg_date': '2010-09-27'},
#  {'domain': 'www.goowle.com',
#   'puny_code_domain': '',
#   'ip': '185.107.56.199',
#   'country': 'US',
#   'reg_date': '2020-10-18'},
#  {'domain': 'www.googyle.com',
#   'puny_code_domain': '',
#   'ip': '93.115.28.104',
#   'country': 'PA',
#   'reg_date': '2012-04-23'},
#  {'domain': 'www.goegle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.246',
#   'country': 'CZ',
#   'reg_date': '2000-06-24'},
#  {'domain': 'www.googzle.com',
#   'puny_code_domain': '',
#   'ip': '52.66.233.38',
#   'country': 'CN',
#   'reg_date': '2024-01-03'},
#  {'domain': 'www.gogole.com',
#   'puny_code_domain': '',
#   'ip': '216.58.204.67',
#   'country': 'US',
#   'reg_date': '2000-04-10'},
#  {'domain': 'www.guogle.com',
#   'puny_code_domain': '',
#   'ip': '64.190.63.222',
#   'country': 'CA',
#   'reg_date': '2007-10-17'},
#  {'domain': 'www.g.oogle.com',
#   'puny_code_domain': '',
#   'ip': '104.21.19.57',
#   'country': 'IS',
#   'reg_date': '1999-02-07'},
#  {'domain': 'www.goagle.com',
#   'puny_code_domain': '',
#   'ip': '89.145.66.234',
#   'country': 'US',
#   'reg_date': '2004-05-08'},
#  {'domain': 'www.goopgle.com',
#   'puny_code_domain': '',
#   'ip': '95.211.219.66',
#   'country': 'PA',
#   'reg_date': '2003-07-15'},
#  {'domain': 'www.glogle.com',
#   'puny_code_domain': '',
#   'ip': '66.81.203.11',
#   'country': 'US',
#   'reg_date': '2000-10-02'},
#  {'domain': 'www.gogle.com',
#   'puny_code_domain': '',
#   'ip': '142.250.200.3',
#   'country': 'US',
#   'reg_date': '1998-10-20'},
#  {'domain': 'www.g9ogle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.238',
#   'country': '',
#   'reg_date': '2014-05-18'},
#  {'domain': 'www.geogle.com',
#   'puny_code_domain': '',
#   'ip': '78.41.204.38',
#   'country': 'PA',
#   'reg_date': '2002-08-16'},
#  {'domain': 'www.goọgle.com',
#   'puny_code_domain': 'www.xn--gogle-381b.com',
#   'ip': '217.70.184.50',
#   'country': 'FR',
#   'reg_date': '2015-10-01'},
#  {'domain': 'www.gokogle.com',
#   'puny_code_domain': '',
#   'ip': '185.53.178.50',
#   'country': 'US',
#   'reg_date': '2007-05-05'},
#  {'domain': 'www.gkoogle.com',
#   'puny_code_domain': '',
#   'ip': '13.248.169.48',
#   'country': 'US',
#   'reg_date': '2008-08-09'},
#  {'domain': 'www.gpogle.com',
#   'puny_code_domain': '',
#   'ip': '69.162.95.4',
#   'country': 'BS',
#   'reg_date': '2002-03-13'},
#  {'domain': 'www.go-ogle.com',
#   'puny_code_domain': '',
#   'ip': '66.96.149.22',
#   'country': 'US',
#   'reg_date': '2002-03-10'},
#  {'domain': 'www.gaogle.com',
#   'puny_code_domain': '',
#   'ip': '107.180.51.12',
#   'country': '',
#   'reg_date': '2002-10-08'},
#  {'domain': 'www.gioogle.com',
#   'puny_code_domain': '',
#   'ip': '185.53.178.51',
#   'country': 'IN',
#   'reg_date': '2002-10-04'},
#  {'domain': 'www.gooogle.com',
#   'puny_code_domain': '',
#   'ip': '172.217.169.67',
#   'country': 'US',
#   'reg_date': '2000-03-02'},
#  {'domain': 'www.go9ogle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.250',
#   'country': 'CN',
#   'reg_date': '2002-09-19'},
#  {'domain': 'www.boogle.com',
#   'puny_code_domain': '',
#   'ip': '13.248.169.48',
#   'country': '',
#   'reg_date': '1999-06-21'},
#  {'domain': 'www.voogle.com',
#   'puny_code_domain': '',
#   'ip': '3.64.163.50',
#   'country': '',
#   'reg_date': '2002-05-16'},
#  {'domain': 'www.ogogle.com',
#   'puny_code_domain': '',
#   'ip': '142.250.200.35',
#   'country': 'US',
#   'reg_date': '2003-08-15'},
#  {'domain': 'www.g0ogle.com',
#   'puny_code_domain': '',
#   'ip': '64.91.249.20',
#   'country': '',
#   'reg_date': '2001-10-19'},
#  {'domain': 'www.gpoogle.com',
#   'puny_code_domain': '',
#   'ip': '104.143.9.110',
#   'country': '',
#   'reg_date': '2001-09-06'},
#  {'domain': 'www.gopogle.com',
#   'puny_code_domain': '',
#   'ip': '173.44.37.208',
#   'country': 'US',
#   'reg_date': '2001-10-22'},
#  {'domain': 'www.oogle.com',
#   'puny_code_domain': '',
#   'ip': '104.21.19.57',
#   'country': 'IS',
#   'reg_date': '1999-02-07'},
#  {'domain': 'www.g9oogle.com',
#   'puny_code_domain': '',
#   'ip': '52.33.207.7',
#   'country': 'US',
#   'reg_date': '2023-04-23'},
#  {'domain': 'www.gvoogle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.246',
#   'country': 'CZ',
#   'reg_date': '2023-10-29'},
#  {'domain': 'www.göogle.com',
#   'puny_code_domain': 'www.xn--gogle-jua.com',
#   'ip': '3.33.130.190',
#   'country': '',
#   'reg_date': '2019-10-30'},
#  {'domain': 'www.vgoogle.com',
#   'puny_code_domain': '',
#   'ip': '47.254.33.193',
#   'country': 'CN',
#   'reg_date': '2009-09-26'},
#  {'domain': 'www.ggoogle.com',
#   'puny_code_domain': '',
#   'ip': '142.250.178.3',
#   'country': 'US',
#   'reg_date': '2000-07-04'},
#  {'domain': 'www.toogle.com',
#   'puny_code_domain': '',
#   'ip': '3.33.130.190',
#   'country': '',
#   'reg_date': '2001-03-30'},
#  {'domain': 'www.gọogle.com',
#   'puny_code_domain': 'www.xn--gogle-281b.com',
#   'ip': '99.83.176.46',
#   'country': '',
#   'reg_date': '2021-10-13'},
#  {'domain': 'www.gyoogle.com',
#   'puny_code_domain': '',
#   'ip': '199.59.243.225',
#   'country': '',
#   'reg_date': '2010-11-11'},
#  {'domain': 'www.hgoogle.com',
#   'puny_code_domain': '',
#   'ip': '173.44.37.208',
#   'country': '',
#   'reg_date': '2000-11-09'},
#  {'domain': 'www.bgoogle.com',
#   'puny_code_domain': '',
#   'ip': '45.58.190.82',
#   'country': 'US',
#   'reg_date': '2003-04-18'},
#  {'domain': 'www.gboogle.com',
#   'puny_code_domain': '',
#   'ip': '185.107.56.202',
#   'country': 'PA',
#   'reg_date': '2002-09-19'},
#  {'domain': 'www.zoogle.com',
#   'puny_code_domain': '',
#   'ip': '192.254.233.61',
#   'country': 'US',
#   'reg_date': '2001-06-01'},
#  {'domain': 'www.yoogle.com',
#   'puny_code_domain': '',
#   'ip': '127.0.0.1',
#   'country': 'US',
#   'reg_date': '2000-01-31'},
#  {'domain': 'www.tgoogle.com',
#   'puny_code_domain': '',
#   'ip': '198.251.81.30',
#   'country': '',
#   'reg_date': '2001-10-22'},
#  {'domain': 'www.fgoogle.com',
#   'puny_code_domain': '',
#   'ip': '127.0.0.10',
#   'country': 'PA',
#   'reg_date': '2001-08-29'},
#  {'domain': 'www.google.in',
#   'puny_code_domain': '',
#   'ip': '216.58.204.67',
#   'country': '',
#   'reg_date': ''},
#  {'domain': 'www.google.ru',
#   'puny_code_domain': '',
#   'ip': '142.250.178.3',
#   'country': '',
#   'reg_date': ''},
#  {'domain': 'www.ĝoogle.com',
#   'puny_code_domain': 'www.xn--oogle-60a.com',
#   'ip': '64.225.91.73',
#   'country': '',
#   'reg_date': '2023-07-10'},
#  {'domain': 'www.google.ml',
#   'puny_code_domain': '',
#   'ip': '142.250.187.227',
#   'country': '',
#   'reg_date': ''},
#  {'domain': 'www.foogle.com',
#   'puny_code_domain': '',
#   'ip': '173.236.255.36',
#   'country': 'US',
#   'reg_date': '1999-06-27'},
#  {'domain': 'www.google.io',
#   'puny_code_domain': '',
#   'ip': '142.250.180.3',
#   'country': '',
#   'reg_date': ''},
#  {'domain': 'www.google.cf',
#   'puny_code_domain': '',
#   'ip': '142.250.200.3',
#   'country': '',
#   'reg_date': ''},
#  {'domain': 'www.woogle.com',
#   'puny_code_domain': '',
#   'ip': '64.98.135.11',
#   'country': 'RU',
#   'reg_date': '2002-04-14'},
#  {'domain': 'www.googlecom.com',
#   'puny_code_domain': '',
#   'ip': '172.217.16.227',
#   'country': 'US',
#   'reg_date': '2000-04-28'},
#  {'domain': 'account-verify-google.com',
#   'puny_code_domain': '',
#   'ip': '65.108.50.121',
#   'country': 'IL',
#   'reg_date': '2023-09-04'},
#  {'domain': 'www.google.ga',
#   'puny_code_domain': '',
#   'ip': '216.58.212.195',
#   'country': '',
#   'reg_date': ''},
#  {'domain': 'www.google.com',
#   'puny_code_domain': '',
#   'ip': '142.250.200.36',
#   'country': 'US',
#   'reg_date': '1997-09-15'},
#  {'domain': 'login-google.com',
#   'puny_code_domain': '',
#   'ip': '20.42.95.243',
#   'country': 'US',
#   'reg_date': '2016-10-18'},
#  {'domain': 'www.google.cn',
#   'puny_code_domain': '',
#   'ip': '216.58.201.99',
#   'country': '',
#   'reg_date': ''},
#  {'domain': 'www.google.info',
#   'puny_code_domain': '',
#   'ip': '142.250.179.227',
#   'country': 'US',
#   'reg_date': '2001-07-31'},
#  {'domain': 'auth-google.com',
#   'puny_code_domain': '',
#   'ip': '128.199.247.177',
#   'country': 'US',
#   'reg_date': '2019-06-13'},
#  {'domain': 'security-google.com',
#   'puny_code_domain': '',
#   'ip': '142.250.180.14',
#   'country': 'cn',
#   'reg_date': '2014-06-17'}]

# %% [markdown]
# # VirusTotal Report Generation Code
#
# ### Note: Few domains country and registration date which was not available in the whois command output is pulled using the "whois" data available in the VirusTotal API response.

# %%
"""
Virus Total API integration module

"""
import re
import json
import base64
import requests


VT_ENDPOINT = "https://www.virustotal.com"

class VTReport:
    """
        This class checks an IP on Virus Total

    Attribute:
        ip: str
            ip address
            
        api_key: str
                 VirusTotal API key
    """
    def __init__(self, ip: str, api_key: str):
        self.ip = ip
        self.api_key = api_key

    def decode_api_key(self):
        """
            This method decodes base64 encoded api_key

        Returns:
            str: decoded api_key
        """
        return base64.b64decode(self.api_key)
    
    def update_api_key(self):
        """
            This method updates the api_key with the decoded api_key
        
        """
        self.api_key = self.decode_api_key()
        
    def get_domain_report(self) -> tuple:
        """
            This method get the Virus Total report for an IP

        Returns:
            Returns the required Virus Total report details
            Eg:
            True,
            {
                last_analysis_stats:{
                                "malicious": 5,
                                "suspicious": 0,
                                "harmless": 60
                            }
            }
        """
        try:
            url = f"{VT_ENDPOINT}/api/v3/ip_addresses/{self.ip}"
            headers = {
                "accept": "application/json",
                "x-apikey": self.api_key
            }
            response = requests.get(url, headers=headers, timeout=60)
            vt_data = json.loads(response.text)
            if response.status_code == 200:
                if "data" in vt_data and \
                    "attributes" in vt_data['data'] and \
                    "last_analysis_stats" in vt_data['data']['attributes']:
                    last_analysis_stats = vt_data["data"]["attributes"]["last_analysis_stats"]
                    del last_analysis_stats["timeout"]
                    del last_analysis_stats["undetected"]
                    #"whois" data available in the VirusTotal API response
                    whois_data = vt_data["data"]["attributes"]["whois"]
                    country, reg_date = self.process_whois(whois_data)
                    return True, {"last_analysis_stats":last_analysis_stats, \
                                  "country": country, "reg_date": reg_date}
                else:
                    return False, "Required details not found in the api response"
            else:
                return False, str(response.content)
        except Exception as e:
            return False, f"Exception: {str(e)}"
        
    def process_whois(self, whois: str) -> tuple:
        country = ""
        reg_date = ""
        country_pattern = r"Country: (\w+)"
        regdate_pattern = r"RegDate: (\d{4}-\d{2}-\d{2})"
        country_match = re.search(country_pattern, whois)
        if country_match:
            country = country_match.group(1)
        regdate_match = re.search(regdate_pattern, whois)
        if regdate_match:
            reg_date = regdate_match.group(1)
        return country, reg_date

    def main(self) -> tuple:
        """
            Main function to generate a domain VT report
        """
        self.update_api_key()
        return self.get_domain_report()
    
if __name__ == '__main__':
    for item in new_output:
        #Base64 encoded VirusTotal API Key
        encoded_api_key = "ZjkzNzIxOGJjOTE0YmIxMGE4YWM1ZDkzMTRkMGZjNjIxZWRkYjVmNDZlMmQ5NGUwOGE1ZTQzMGNjNzJjNDg4YQ=="
        status, data = VTReport(item['ip'], encoded_api_key).main()
        if status:
            item.update(data['last_analysis_stats'])
            if item["country"] == "":
                item.update({"country":data["country"]})
            if item["reg_date"] == "":
                item.update({"reg_date":data["reg_date"]})
    print(new_output)
# Out:
# [{'domain': 'www.google.org', 'puny_code_domain': '', 'ip': '216.239.32.27', 'country': 'US', 'reg_date': '1998-10-21', 'malicious': 0, 'suspicious': 0, 'harmless': 66}, {'domain': 'ww.google.com', 'puny_code_domain': '', 'ip': '142.250.200.46', 'country': 'US', 'reg_date': '1997-09-15', 'malicious': 0, 'suspicious': 0, 'harmless': 67}, {'domain': 'www.google.co', 'puny_code_domain': '', 'ip': '142.250.187.206', 'country': 'US', 'reg_date': '2012-05-24', 'malicious': 0, 'suspicious': 0, 'harmless': 66}, {'domain': 'www.google.net', 'puny_code_domain': '', 'ip': '142.250.200.36', 'country': 'US', 'reg_date': '1999-03-15', 'malicious': 0, 'suspicious': 0, 'harmless': 66}, {'domain': 'www.google.de', 'puny_code_domain': '', 'ip': '172.217.16.227', 'country': 'US', 'reg_date': '2012-04-16', 'malicious': 0, 'suspicious': 0, 'harmless': 66}, {'domain': 'www.google.tk', 'puny_code_domain': '', 'ip': '142.250.200.3', 'country': 'US', 'reg_date': '2012-05-24', 'malicious': 0, 'suspicious': 0, 'harmless': 64}, {'domain': 'wwwngoogle.com', 'puny_code_domain': '', 'ip': '199.59.243.225', 'country': '', 'reg_date': '2011-05-16', 'malicious': 9, 'suspicious': 0, 'harmless': 58}, {'domain': 'wwwgoogle.com', 'puny_code_domain': '', 'ip': '216.58.212.228', 'country': 'US', 'reg_date': '1999-03-03', 'malicious': 2, 'suspicious': 0, 'harmless': 64}, {'domain': 'www.go0ogle.com', 'puny_code_domain': '', 'ip': '95.211.189.138', 'country': 'PA', 'reg_date': '2002-09-01', 'malicious': 1, 'suspicious': 0, 'harmless': 64}, {'domain': 'www.gookgle.com', 'puny_code_domain': '', 'ip': '103.224.182.226', 'country': '', 'reg_date': '2008-07-21', 'malicious': 2, 'suspicious': 0, 'harmless': 62}, {'domain': 'wwwg.oogle.com', 'puny_code_domain': '', 'ip': '104.21.19.57', 'country': 'IS', 'reg_date': '1999-02-07', 'malicious': 0, 'suspicious': 0, 'harmless': 65}, {'domain': 'www.googlwe.com', 'puny_code_domain': '', 'ip': '95.211.189.137', 'country': 'US', 'reg_date': '2000-11-13', 'malicious': 0, 'suspicious': 1, 'harmless': 65}, {'domain': 'www.googloe.com', 'puny_code_domain': '', 'ip': '78.41.204.34', 'country': 'US', 'reg_date': '2000-11-09', 'malicious': 0, 'suspicious': 0, 'harmless': 67}, {'domain': 'www.goozle.com', 'puny_code_domain': '', 'ip': '50.62.97.1', 'country': 'US', 'reg_date': '1999-10-04', 'malicious': 0, 'suspicious': 0, 'harmless': 0}, {'domain': 'www.goohle.com', 'puny_code_domain': '', 'ip': '47.254.33.193', 'country': 'CN', 'reg_date': '2002-06-03', 'malicious': 1, 'suspicious': 0, 'harmless': 63}, {'domain': 'www.googl.com', 'puny_code_domain': '', 'ip': '172.217.16.227', 'country': 'US', 'reg_date': '2001-01-24', 'malicious': 0, 'suspicious': 0, 'harmless': 66}, {'domain': 'www.gooyle.com', 'puny_code_domain': '', 'ip': '66.81.203.201', 'country': 'US', 'reg_date': '2000-10-02', 'malicious': 0, 'suspicious': 0, 'harmless': 63}, {'domain': 'www.googlde.com', 'puny_code_domain': '', 'ip': '13.248.169.48', 'country': 'US', 'reg_date': '2002-12-01', 'malicious': 5, 'suspicious': 2, 'harmless': 60}, {'domain': 'www.googlr.com', 'puny_code_domain': '', 'ip': '142.250.187.195', 'country': 'US', 'reg_date': '2001-05-29', 'malicious': 1, 'suspicious': 0, 'harmless': 65}, {'domain': 'www.gootle.com', 'puny_code_domain': '', 'ip': '66.81.203.201', 'country': 'US', 'reg_date': '2000-10-02', 'malicious': 0, 'suspicious': 0, 'harmless': 63}, {'domain': 'www.googl4.com', 'puny_code_domain': '', 'ip': '103.224.182.245', 'country': '', 'reg_date': '2007-10-04', 'malicious': 0, 'suspicious': 0, 'harmless': 66}, {'domain': 'www.googli.com', 'puny_code_domain': '', 'ip': '162.255.119.253', 'country': 'CN', 'reg_date': '2012-09-04', 'malicious': 0, 'suspicious': 0, 'harmless': 54}, {'domain': 'www.googlè.com', 'puny_code_domain': 'www.xn--googl-8ra.com', 'ip': '217.160.0.119', 'country': 'FR', 'reg_date': '2023-12-21', 'malicious': 0, 'suspicious': 0, 'harmless': 64}, {'domain': 'www.googlě.com', 'puny_code_domain': 'www.xn--googl-z0a.com', 'ip': '213.1 ...

# %%
vt_report = copy.deepcopy(new_output)
vt_report
# Out:
# [{'domain': 'www.google.org',
#   'puny_code_domain': '',
#   'ip': '216.239.32.27',
#   'country': 'US',
#   'reg_date': '1998-10-21',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'ww.google.com',
#   'puny_code_domain': '',
#   'ip': '142.250.200.46',
#   'country': 'US',
#   'reg_date': '1997-09-15',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 67},
#  {'domain': 'www.google.co',
#   'puny_code_domain': '',
#   'ip': '142.250.187.206',
#   'country': 'US',
#   'reg_date': '2012-05-24',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'www.google.net',
#   'puny_code_domain': '',
#   'ip': '142.250.200.36',
#   'country': 'US',
#   'reg_date': '1999-03-15',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'www.google.de',
#   'puny_code_domain': '',
#   'ip': '172.217.16.227',
#   'country': 'US',
#   'reg_date': '2012-04-16',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'www.google.tk',
#   'puny_code_domain': '',
#   'ip': '142.250.200.3',
#   'country': 'US',
#   'reg_date': '2012-05-24',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'wwwngoogle.com',
#   'puny_code_domain': '',
#   'ip': '199.59.243.225',
#   'country': '',
#   'reg_date': '2011-05-16',
#   'malicious': 9,
#   'suspicious': 0,
#   'harmless': 58},
#  {'domain': 'wwwgoogle.com',
#   'puny_code_domain': '',
#   'ip': '216.58.212.228',
#   'country': 'US',
#   'reg_date': '1999-03-03',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.go0ogle.com',
#   'puny_code_domain': '',
#   'ip': '95.211.189.138',
#   'country': 'PA',
#   'reg_date': '2002-09-01',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.gookgle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.226',
#   'country': '',
#   'reg_date': '2008-07-21',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'wwwg.oogle.com',
#   'puny_code_domain': '',
#   'ip': '104.21.19.57',
#   'country': 'IS',
#   'reg_date': '1999-02-07',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.googlwe.com',
#   'puny_code_domain': '',
#   'ip': '95.211.189.137',
#   'country': 'US',
#   'reg_date': '2000-11-13',
#   'malicious': 0,
#   'suspicious': 1,
#   'harmless': 65},
#  {'domain': 'www.googloe.com',
#   'puny_code_domain': '',
#   'ip': '78.41.204.34',
#   'country': 'US',
#   'reg_date': '2000-11-09',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 67},
#  {'domain': 'www.goozle.com',
#   'puny_code_domain': '',
#   'ip': '50.62.97.1',
#   'country': 'US',
#   'reg_date': '1999-10-04',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 0},
#  {'domain': 'www.goohle.com',
#   'puny_code_domain': '',
#   'ip': '47.254.33.193',
#   'country': 'CN',
#   'reg_date': '2002-06-03',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googl.com',
#   'puny_code_domain': '',
#   'ip': '172.217.16.227',
#   'country': 'US',
#   'reg_date': '2001-01-24',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'www.gooyle.com',
#   'puny_code_domain': '',
#   'ip': '66.81.203.201',
#   'country': 'US',
#   'reg_date': '2000-10-02',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googlde.com',
#   'puny_code_domain': '',
#   'ip': '13.248.169.48',
#   'country': 'US',
#   'reg_date': '2002-12-01',
#   'malicious': 5,
#   'suspicious': 2,
#   'harmless': 60},
#  {'domain': 'www.googlr.com',
#   'puny_code_domain': '',
#   'ip': '142.250.187.195',
#   'country': 'US',
#   'reg_date': '2001-05-29',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.gootle.com',
#   'puny_code_domain': '',
#   'ip': '66.81.203.201',
#   'country': 'US',
#   'reg_date': '2000-10-02',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googl4.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.245',
#   'country': '',
#   'reg_date': '2007-10-04',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'www.googli.com',
#   'puny_code_domain': '',
#   'ip': '162.255.119.253',
#   'country': 'CN',
#   'reg_date': '2012-09-04',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 54},
#  {'domain': 'www.googlè.com',
#   'puny_code_domain': 'www.xn--googl-8ra.com',
#   'ip': '217.160.0.119',
#   'country': 'FR',
#   'reg_date': '2023-12-21',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.googlě.com',
#   'puny_code_domain': 'www.xn--googl-z0a.com',
#   'ip': '213.186.33.5',
#   'country': 'FR',
#   'reg_date': '2022-01-14',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.google4.com',
#   'puny_code_domain': '',
#   'ip': '185.53.177.54',
#   'country': '',
#   'reg_date': '2004-06-11',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.googlė.com',
#   'puny_code_domain': 'www.xn--googl-b0a.com',
#   'ip': '185.53.178.53',
#   'country': 'US',
#   'reg_date': '2015-11-05',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.googlez.com',
#   'puny_code_domain': '',
#   'ip': '13.248.169.48',
#   'country': 'US',
#   'reg_date': '2023-04-26',
#   'malicious': 5,
#   'suspicious': 2,
#   'harmless': 60},
#  {'domain': 'www.googlze.com',
#   'puny_code_domain': '',
#   'ip': '75.2.115.196',
#   'country': 'US',
#   'reg_date': '2010-11-18',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googlé.com',
#   'puny_code_domain': 'www.xn--googl-fsa.com',
#   'ip': '69.162.95.6',
#   'country': 'US',
#   'reg_date': '2011-10-06',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 61},
#  {'domain': 'www.googlz.com',
#   'puny_code_domain': '',
#   'ip': '202.31.187.154',
#   'country': 'KR',
#   'reg_date': '2005-03-18',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.googleq.com',
#   'puny_code_domain': '',
#   'ip': '185.53.178.53',
#   'country': 'US',
#   'reg_date': '2020-09-01',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.googlê.com',
#   'puny_code_domain': 'www.xn--googl-lsa.com',
#   'ip': '38.92.48.160',
#   'country': 'IS',
#   'reg_date': '2024-03-13',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.googlm.com',
#   'puny_code_domain': '',
#   'ip': '204.16.193.4',
#   'country': 'US',
#   'reg_date': '2003-12-18',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 0},
#  {'domain': 'www.googley.com',
#   'puny_code_domain': '',
#   'ip': '85.233.160.215',
#   'country': 'GB',
#   'reg_date': '1999-10-19',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.googlet.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.239',
#   'country': 'US',
#   'reg_date': '2005-08-21',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googlew.com',
#   'puny_code_domain': '',
#   'ip': '209.141.38.71',
#   'country': 'US',
#   'reg_date': '2001-10-20',
#   'malicious': 6,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googlen.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.239',
#   'country': 'US',
#   'reg_date': '2005-08-21',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googlee.com',
#   'puny_code_domain': '',
#   'ip': '142.250.200.3',
#   'country': 'US',
#   'reg_date': '2000-04-06',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.googleb.com',
#   'puny_code_domain': '',
#   'ip': '47.254.33.193',
#   'country': 'CN',
#   'reg_date': '2010-12-28',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googleh.com',
#   'puny_code_domain': '',
#   'ip': '75.2.103.221',
#   'country': 'IM',
#   'reg_date': '2023-12-20',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.googlem.com',
#   'puny_code_domain': '',
#   'ip': '45.58.190.82',
#   'country': 'US',
#   'reg_date': '2000-11-20',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.googel.com',
#   'puny_code_domain': '',
#   'ip': '142.250.187.227',
#   'country': 'US',
#   'reg_date': '2001-01-24',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.googlek.com',
#   'puny_code_domain': '',
#   'ip': '3.64.163.50',
#   'country': '',
#   'reg_date': '2020-08-25',
#   'malicious': 6,
#   'suspicious': 1,
#   'harmless': 61},
#  {'domain': 'www.googlec.com',
#   'puny_code_domain': '',
#   'ip': '3.64.163.50',
#   'country': 'US',
#   'reg_date': '2001-02-17',
#   'malicious': 6,
#   'suspicious': 1,
#   'harmless': 61},
#  {'domain': 'www.googleg.com',
#   'puny_code_domain': '',
#   'ip': '76.223.35.103',
#   'country': 'US',
#   'reg_date': '2024-01-09',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.googlei.com',
#   'puny_code_domain': '',
#   'ip': '162.210.199.87',
#   'country': 'US',
#   'reg_date': '2003-01-17',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.googoe.com',
#   'puny_code_domain': '',
#   'ip': '66.81.203.11',
#   'country': 'US',
#   'reg_date': '2000-10-02',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 61},
#  {'domain': 'www.googlle.com',
#   'puny_code_domain': '',
#   'ip': '104.21.83.75',
#   'country': 'US',
#   'reg_date': '2000-06-29',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.googlpe.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.207',
#   'country': '',
#   'reg_date': '2003-08-24',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googhe.com',
#   'puny_code_domain': '',
#   'ip': '199.59.243.225',
#   'country': 'US',
#   'reg_date': '2002-08-08',
#   'malicious': 9,
#   'suspicious': 0,
#   'harmless': 58},
#  {'domain': 'www.googlme.com',
#   'puny_code_domain': '',
#   'ip': '116.202.118.107',
#   'country': 'US',
#   'reg_date': '2005-04-27',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.googple.com',
#   'puny_code_domain': '',
#   'ip': '103.224.212.210',
#   'country': 'US',
#   'reg_date': '2023-07-29',
#   'malicious': 10,
#   'suspicious': 0,
#   'harmless': 57},
#  {'domain': 'www.googmle.com',
#   'puny_code_domain': '',
#   'ip': '64.91.248.15',
#   'country': 'US',
#   'reg_date': '2004-02-22',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.googme.com',
#   'puny_code_domain': '',
#   'ip': '199.59.243.225',
#   'country': 'US',
#   'reg_date': '2002-08-08',
#   'malicious': 9,
#   'suspicious': 0,
#   'harmless': 58},
#  {'domain': 'www.googlke.com',
#   'puny_code_domain': '',
#   'ip': '64.32.22.102',
#   'country': '',
#   'reg_date': '2000-11-13',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.goo.gle.com',
#   'puny_code_domain': '',
#   'ip': '13.248.169.48',
#   'country': 'US',
#   'reg_date': '2001-12-29',
#   'malicious': 5,
#   'suspicious': 2,
#   'harmless': 60},
#  {'domain': 'www.goog-le.com',
#   'puny_code_domain': '',
#   'ip': '74.208.236.69',
#   'country': 'US',
#   'reg_date': '2004-11-24',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.googe.com',
#   'puny_code_domain': '',
#   'ip': '162.243.10.151',
#   'country': 'US',
#   'reg_date': '1998-10-02',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.googłe.com',
#   'puny_code_domain': 'www.xn--googe-n7a.com',
#   'ip': '46.4.60.204',
#   'country': 'TR',
#   'reg_date': '2016-02-03',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 0},
#  {'domain': 'www.goolge.com',
#   'puny_code_domain': '',
#   'ip': '216.58.212.227',
#   'country': 'US',
#   'reg_date': '1999-06-04',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'www.googvle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.207',
#   'country': '',
#   'reg_date': '2003-08-24',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.goole.com',
#   'puny_code_domain': '',
#   'ip': '217.160.0.201',
#   'country': 'GB',
#   'reg_date': '1999-11-09',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.goovle.com',
#   'puny_code_domain': '',
#   'ip': '162.210.199.65',
#   'country': 'BS',
#   'reg_date': '2017-09-23',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.goofgle.com',
#   'puny_code_domain': '',
#   'ip': '185.53.178.50',
#   'country': '',
#   'reg_date': '2004-09-23',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googfle.com',
#   'puny_code_domain': '',
#   'ip': '185.53.177.53',
#   'country': 'US',
#   'reg_date': '2008-11-13',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googie.com',
#   'puny_code_domain': '',
#   'ip': '209.17.116.160',
#   'country': 'US',
#   'reg_date': '1998-01-21',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.goobgle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.238',
#   'country': '',
#   'reg_date': '2011-12-07',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.gooble.com',
#   'puny_code_domain': '',
#   'ip': '64.190.63.222',
#   'country': 'IS',
#   'reg_date': '1999-07-27',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 61},
#  {'domain': 'www.goofle.com',
#   'puny_code_domain': '',
#   'ip': '162.210.199.65',
#   'country': 'US',
#   'reg_date': '1999-07-30',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.gooǥle.com',
#   'puny_code_domain': 'www.xn--goole-k0b.com',
#   'ip': '216.58.201.110',
#   'country': 'US',
#   'reg_date': '2017-03-23',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 67},
#  {'domain': 'www.googble.com',
#   'puny_code_domain': '',
#   'ip': '72.52.178.23',
#   'country': 'TH',
#   'reg_date': '2002-02-19',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.goohgle.com',
#   'puny_code_domain': '',
#   'ip': '104.252.32.152',
#   'country': '',
#   'reg_date': '2023-11-03',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 0},
#  {'domain': 'www.go9gle.com',
#   'puny_code_domain': '',
#   'ip': '64.190.63.222',
#   'country': 'GE',
#   'reg_date': '2010-09-27',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 61},
#  {'domain': 'www.goowle.com',
#   'puny_code_domain': '',
#   'ip': '185.107.56.199',
#   'country': 'US',
#   'reg_date': '2020-10-18',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.googyle.com',
#   'puny_code_domain': '',
#   'ip': '93.115.28.104',
#   'country': 'PA',
#   'reg_date': '2012-04-23',
#   'malicious': 4,
#   'suspicious': 1,
#   'harmless': 62},
#  {'domain': 'www.goegle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.246',
#   'country': 'CZ',
#   'reg_date': '2000-06-24',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.googzle.com',
#   'puny_code_domain': '',
#   'ip': '52.66.233.38',
#   'country': 'CN',
#   'reg_date': '2024-01-03',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 0},
#  {'domain': 'www.gogole.com',
#   'puny_code_domain': '',
#   'ip': '216.58.204.67',
#   'country': 'US',
#   'reg_date': '2000-04-10',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 67},
#  {'domain': 'www.guogle.com',
#   'puny_code_domain': '',
#   'ip': '64.190.63.222',
#   'country': 'CA',
#   'reg_date': '2007-10-17',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 61},
#  {'domain': 'www.g.oogle.com',
#   'puny_code_domain': '',
#   'ip': '104.21.19.57',
#   'country': 'IS',
#   'reg_date': '1999-02-07',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.goagle.com',
#   'puny_code_domain': '',
#   'ip': '89.145.66.234',
#   'country': 'US',
#   'reg_date': '2004-05-08',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 0},
#  {'domain': 'www.goopgle.com',
#   'puny_code_domain': '',
#   'ip': '95.211.219.66',
#   'country': 'PA',
#   'reg_date': '2003-07-15',
#   'malicious': 2,
#   'suspicious': 1,
#   'harmless': 64},
#  {'domain': 'www.glogle.com',
#   'puny_code_domain': '',
#   'ip': '66.81.203.11',
#   'country': 'US',
#   'reg_date': '2000-10-02',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 61},
#  {'domain': 'www.gogle.com',
#   'puny_code_domain': '',
#   'ip': '142.250.200.3',
#   'country': 'US',
#   'reg_date': '1998-10-20',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.g9ogle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.238',
#   'country': '',
#   'reg_date': '2014-05-18',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.geogle.com',
#   'puny_code_domain': '',
#   'ip': '78.41.204.38',
#   'country': 'PA',
#   'reg_date': '2002-08-16',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'www.goọgle.com',
#   'puny_code_domain': 'www.xn--gogle-381b.com',
#   'ip': '217.70.184.50',
#   'country': 'FR',
#   'reg_date': '2015-10-01',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.gokogle.com',
#   'puny_code_domain': '',
#   'ip': '185.53.178.50',
#   'country': 'US',
#   'reg_date': '2007-05-05',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.gkoogle.com',
#   'puny_code_domain': '',
#   'ip': '13.248.169.48',
#   'country': 'US',
#   'reg_date': '2008-08-09',
#   'malicious': 5,
#   'suspicious': 2,
#   'harmless': 60},
#  {'domain': 'www.gpogle.com',
#   'puny_code_domain': '',
#   'ip': '69.162.95.4',
#   'country': 'BS',
#   'reg_date': '2002-03-13',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.go-ogle.com',
#   'puny_code_domain': '',
#   'ip': '66.96.149.22',
#   'country': 'US',
#   'reg_date': '2002-03-10',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.gaogle.com',
#   'puny_code_domain': '',
#   'ip': '107.180.51.12',
#   'country': 'US',
#   'reg_date': '2002-10-08',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.gioogle.com',
#   'puny_code_domain': '',
#   'ip': '185.53.178.51',
#   'country': 'IN',
#   'reg_date': '2002-10-04',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 61},
#  {'domain': 'www.gooogle.com',
#   'puny_code_domain': '',
#   'ip': '172.217.169.67',
#   'country': 'US',
#   'reg_date': '2000-03-02',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.go9ogle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.250',
#   'country': 'CN',
#   'reg_date': '2002-09-19',
#   'malicious': 3,
#   'suspicious': 2,
#   'harmless': 63},
#  {'domain': 'www.boogle.com',
#   'puny_code_domain': '',
#   'ip': '13.248.169.48',
#   'country': 'US',
#   'reg_date': '1999-06-21',
#   'malicious': 5,
#   'suspicious': 2,
#   'harmless': 60},
#  {'domain': 'www.voogle.com',
#   'puny_code_domain': '',
#   'ip': '3.64.163.50',
#   'country': '',
#   'reg_date': '2002-05-16',
#   'malicious': 6,
#   'suspicious': 1,
#   'harmless': 61},
#  {'domain': 'www.ogogle.com',
#   'puny_code_domain': '',
#   'ip': '142.250.200.35',
#   'country': 'US',
#   'reg_date': '2003-08-15',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.g0ogle.com',
#   'puny_code_domain': '',
#   'ip': '64.91.249.20',
#   'country': 'US',
#   'reg_date': '2001-10-19',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.gpoogle.com',
#   'puny_code_domain': '',
#   'ip': '104.143.9.110',
#   'country': 'US',
#   'reg_date': '2001-09-06',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 61},
#  {'domain': 'www.gopogle.com',
#   'puny_code_domain': '',
#   'ip': '173.44.37.208',
#   'country': 'US',
#   'reg_date': '2001-10-22',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.oogle.com',
#   'puny_code_domain': '',
#   'ip': '104.21.19.57',
#   'country': 'IS',
#   'reg_date': '1999-02-07',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.g9oogle.com',
#   'puny_code_domain': '',
#   'ip': '52.33.207.7',
#   'country': 'US',
#   'reg_date': '2023-04-23',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.gvoogle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.246',
#   'country': 'CZ',
#   'reg_date': '2023-10-29',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.göogle.com',
#   'puny_code_domain': 'www.xn--gogle-jua.com',
#   'ip': '3.33.130.190',
#   'country': '',
#   'reg_date': '2019-10-30',
#   'malicious': 6,
#   'suspicious': 1,
#   'harmless': 62},
#  {'domain': 'www.vgoogle.com',
#   'puny_code_domain': '',
#   'ip': '47.254.33.193',
#   'country': 'CN',
#   'reg_date': '2009-09-26',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.ggoogle.com',
#   'puny_code_domain': '',
#   'ip': '142.250.178.3',
#   'country': 'US',
#   'reg_date': '2000-07-04',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.toogle.com',
#   'puny_code_domain': '',
#   'ip': '3.33.130.190',
#   'country': '',
#   'reg_date': '2001-03-30',
#   'malicious': 6,
#   'suspicious': 1,
#   'harmless': 62},
#  {'domain': 'www.gọogle.com',
#   'puny_code_domain': 'www.xn--gogle-281b.com',
#   'ip': '99.83.176.46',
#   'country': 'US',
#   'reg_date': '2021-10-13',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'www.gyoogle.com',
#   'puny_code_domain': '',
#   'ip': '199.59.243.225',
#   'country': '',
#   'reg_date': '2010-11-11',
#   'malicious': 9,
#   'suspicious': 0,
#   'harmless': 58},
#  {'domain': 'www.hgoogle.com',
#   'puny_code_domain': '',
#   'ip': '173.44.37.208',
#   'country': '',
#   'reg_date': '2000-11-09',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.bgoogle.com',
#   'puny_code_domain': '',
#   'ip': '45.58.190.82',
#   'country': 'US',
#   'reg_date': '2003-04-18',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.gboogle.com',
#   'puny_code_domain': '',
#   'ip': '185.107.56.202',
#   'country': 'PA',
#   'reg_date': '2002-09-19',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.zoogle.com',
#   'puny_code_domain': '',
#   'ip': '192.254.233.61',
#   'country': 'US',
#   'reg_date': '2001-06-01',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 51},
#  {'domain': 'www.yoogle.com',
#   'puny_code_domain': '',
#   'ip': '127.0.0.1',
#   'country': 'US',
#   'reg_date': '2000-01-31',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.tgoogle.com',
#   'puny_code_domain': '',
#   'ip': '198.251.81.30',
#   'country': 'US',
#   'reg_date': '2001-10-22',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.fgoogle.com',
#   'puny_code_domain': '',
#   'ip': '127.0.0.10',
#   'country': 'PA',
#   'reg_date': '2001-08-29',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.google.in',
#   'puny_code_domain': '',
#   'ip': '216.58.204.67',
#   'country': 'US',
#   'reg_date': '2012-01-27',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 67},
#  {'domain': 'www.google.ru',
#   'puny_code_domain': '',
#   'ip': '142.250.178.3',
#   'country': 'US',
#   'reg_date': '2012-05-24',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.ĝoogle.com',
#   'puny_code_domain': 'www.xn--oogle-60a.com',
#   'ip': '64.225.91.73',
#   'country': 'US',
#   'reg_date': '2023-07-10',
#   'malicious': 5,
#   'suspicious': 0,
#   'harmless': 60},
#  {'domain': 'www.google.ml',
#   'puny_code_domain': '',
#   'ip': '142.250.187.227',
#   'country': 'US',
#   'reg_date': '2012-05-24',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.foogle.com',
#   'puny_code_domain': '',
#   'ip': '173.236.255.36',
#   'country': 'US',
#   'reg_date': '1999-06-27',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 0},
#  {'domain': 'www.google.io',
#   'puny_code_domain': '',
#   'ip': '142.250.180.3',
#   'country': 'US',
#   'reg_date': '2012-05-24',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.google.cf',
#   'puny_code_domain': '',
#   'ip': '142.250.200.3',
#   'country': 'US',
#   'reg_date': '2012-05-24',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.woogle.com',
#   'puny_code_domain': '',
#   'ip': '64.98.135.11',
#   'country': 'RU',
#   'reg_date': '2002-04-14',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.googlecom.com',
#   'puny_code_domain': '',
#   'ip': '172.217.16.227',
#   'country': 'US',
#   'reg_date': '2000-04-28',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'account-verify-google.com',
#   'puny_code_domain': '',
#   'ip': '65.108.50.121',
#   'country': 'IL',
#   'reg_date': '2023-09-04',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 0},
#  {'domain': 'www.google.ga',
#   'puny_code_domain': '',
#   'ip': '216.58.212.195',
#   'country': 'US',
#   'reg_date': '2012-01-27',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'www.google.com',
#   'puny_code_domain': '',
#   'ip': '142.250.200.36',
#   'country': 'US',
#   'reg_date': '1997-09-15',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'login-google.com',
#   'puny_code_domain': '',
#   'ip': '20.42.95.243',
#   'country': 'US',
#   'reg_date': '2016-10-18',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 0},
#  {'domain': 'www.google.cn',
#   'puny_code_domain': '',
#   'ip': '216.58.201.99',
#   'country': 'US',
#   'reg_date': '2012-01-27',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 67},
#  {'domain': 'www.google.info',
#   'puny_code_domain': '',
#   'ip': '142.250.179.227',
#   'country': 'US',
#   'reg_date': '2001-07-31',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'auth-google.com',
#   'puny_code_domain': '',
#   'ip': '128.199.247.177',
#   'country': 'US',
#   'reg_date': '2019-06-13',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 61},
#  {'domain': 'security-google.com',
#   'puny_code_domain': '',
#   'ip': '142.250.180.14',
#   'country': 'cn',
#   'reg_date': '2014-06-17',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65}]

# %%
import pandas as pd

vt_df = pd.DataFrame(vt_report)
vt_df
# Out:
#                   domain puny_code_domain               ip country  \
# 0         www.google.org                     216.239.32.27      US
# 1          ww.google.com                    142.250.200.46      US
# 2          www.google.co                   142.250.187.206      US
# 3         www.google.net                    142.250.200.36      US
# 4          www.google.de                    172.217.16.227      US
# ..                   ...              ...              ...     ...
# 129     login-google.com                      20.42.95.243      US
# 130        www.google.cn                     216.58.201.99      US
# 131      www.google.info                   142.250.179.227      US
# 132      auth-google.com                   128.199.247.177      US
# 133  security-google.com                    142.250.180.14      cn
#
#        reg_date  malicious  suspicious  harmless
# 0    1998-10-21          0           0        66
# 1    1997-09-15          0           0        67
# 2    2012-05-24          0           0        66
# 3    1999-03-15          0           0        66
# 4    2012-04-16          0           0        66
# ..          ...        ...         ...       ...
# 129  2016-10-18          0           0         0
# 130  2012-01-27          0           0        67
# 131  2001-07-31          0           0        64
# 132  2019-06-13          0           0        61
# 133  2014-06-17          0           0        65
#
# [134 rows x 8 columns]

# %%
l_d_input = copy.deepcopy(vt_report)
l_d_input
# Out:
# [{'domain': 'www.google.org',
#   'puny_code_domain': '',
#   'ip': '216.239.32.27',
#   'country': 'US',
#   'reg_date': '1998-10-21',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'ww.google.com',
#   'puny_code_domain': '',
#   'ip': '142.250.200.46',
#   'country': 'US',
#   'reg_date': '1997-09-15',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 67},
#  {'domain': 'www.google.co',
#   'puny_code_domain': '',
#   'ip': '142.250.187.206',
#   'country': 'US',
#   'reg_date': '2012-05-24',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'www.google.net',
#   'puny_code_domain': '',
#   'ip': '142.250.200.36',
#   'country': 'US',
#   'reg_date': '1999-03-15',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'www.google.de',
#   'puny_code_domain': '',
#   'ip': '172.217.16.227',
#   'country': 'US',
#   'reg_date': '2012-04-16',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'www.google.tk',
#   'puny_code_domain': '',
#   'ip': '142.250.200.3',
#   'country': 'US',
#   'reg_date': '2012-05-24',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'wwwngoogle.com',
#   'puny_code_domain': '',
#   'ip': '199.59.243.225',
#   'country': '',
#   'reg_date': '2011-05-16',
#   'malicious': 9,
#   'suspicious': 0,
#   'harmless': 58},
#  {'domain': 'wwwgoogle.com',
#   'puny_code_domain': '',
#   'ip': '216.58.212.228',
#   'country': 'US',
#   'reg_date': '1999-03-03',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.go0ogle.com',
#   'puny_code_domain': '',
#   'ip': '95.211.189.138',
#   'country': 'PA',
#   'reg_date': '2002-09-01',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.gookgle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.226',
#   'country': '',
#   'reg_date': '2008-07-21',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'wwwg.oogle.com',
#   'puny_code_domain': '',
#   'ip': '104.21.19.57',
#   'country': 'IS',
#   'reg_date': '1999-02-07',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.googlwe.com',
#   'puny_code_domain': '',
#   'ip': '95.211.189.137',
#   'country': 'US',
#   'reg_date': '2000-11-13',
#   'malicious': 0,
#   'suspicious': 1,
#   'harmless': 65},
#  {'domain': 'www.googloe.com',
#   'puny_code_domain': '',
#   'ip': '78.41.204.34',
#   'country': 'US',
#   'reg_date': '2000-11-09',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 67},
#  {'domain': 'www.goozle.com',
#   'puny_code_domain': '',
#   'ip': '50.62.97.1',
#   'country': 'US',
#   'reg_date': '1999-10-04',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 0},
#  {'domain': 'www.goohle.com',
#   'puny_code_domain': '',
#   'ip': '47.254.33.193',
#   'country': 'CN',
#   'reg_date': '2002-06-03',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googl.com',
#   'puny_code_domain': '',
#   'ip': '172.217.16.227',
#   'country': 'US',
#   'reg_date': '2001-01-24',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'www.gooyle.com',
#   'puny_code_domain': '',
#   'ip': '66.81.203.201',
#   'country': 'US',
#   'reg_date': '2000-10-02',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googlde.com',
#   'puny_code_domain': '',
#   'ip': '13.248.169.48',
#   'country': 'US',
#   'reg_date': '2002-12-01',
#   'malicious': 5,
#   'suspicious': 2,
#   'harmless': 60},
#  {'domain': 'www.googlr.com',
#   'puny_code_domain': '',
#   'ip': '142.250.187.195',
#   'country': 'US',
#   'reg_date': '2001-05-29',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.gootle.com',
#   'puny_code_domain': '',
#   'ip': '66.81.203.201',
#   'country': 'US',
#   'reg_date': '2000-10-02',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googl4.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.245',
#   'country': '',
#   'reg_date': '2007-10-04',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'www.googli.com',
#   'puny_code_domain': '',
#   'ip': '162.255.119.253',
#   'country': 'CN',
#   'reg_date': '2012-09-04',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 54},
#  {'domain': 'www.googlè.com',
#   'puny_code_domain': 'www.xn--googl-8ra.com',
#   'ip': '217.160.0.119',
#   'country': 'FR',
#   'reg_date': '2023-12-21',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.googlě.com',
#   'puny_code_domain': 'www.xn--googl-z0a.com',
#   'ip': '213.186.33.5',
#   'country': 'FR',
#   'reg_date': '2022-01-14',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.google4.com',
#   'puny_code_domain': '',
#   'ip': '185.53.177.54',
#   'country': '',
#   'reg_date': '2004-06-11',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.googlė.com',
#   'puny_code_domain': 'www.xn--googl-b0a.com',
#   'ip': '185.53.178.53',
#   'country': 'US',
#   'reg_date': '2015-11-05',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.googlez.com',
#   'puny_code_domain': '',
#   'ip': '13.248.169.48',
#   'country': 'US',
#   'reg_date': '2023-04-26',
#   'malicious': 5,
#   'suspicious': 2,
#   'harmless': 60},
#  {'domain': 'www.googlze.com',
#   'puny_code_domain': '',
#   'ip': '75.2.115.196',
#   'country': 'US',
#   'reg_date': '2010-11-18',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googlé.com',
#   'puny_code_domain': 'www.xn--googl-fsa.com',
#   'ip': '69.162.95.6',
#   'country': 'US',
#   'reg_date': '2011-10-06',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 61},
#  {'domain': 'www.googlz.com',
#   'puny_code_domain': '',
#   'ip': '202.31.187.154',
#   'country': 'KR',
#   'reg_date': '2005-03-18',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.googleq.com',
#   'puny_code_domain': '',
#   'ip': '185.53.178.53',
#   'country': 'US',
#   'reg_date': '2020-09-01',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.googlê.com',
#   'puny_code_domain': 'www.xn--googl-lsa.com',
#   'ip': '38.92.48.160',
#   'country': 'IS',
#   'reg_date': '2024-03-13',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.googlm.com',
#   'puny_code_domain': '',
#   'ip': '204.16.193.4',
#   'country': 'US',
#   'reg_date': '2003-12-18',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 0},
#  {'domain': 'www.googley.com',
#   'puny_code_domain': '',
#   'ip': '85.233.160.215',
#   'country': 'GB',
#   'reg_date': '1999-10-19',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.googlet.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.239',
#   'country': 'US',
#   'reg_date': '2005-08-21',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googlew.com',
#   'puny_code_domain': '',
#   'ip': '209.141.38.71',
#   'country': 'US',
#   'reg_date': '2001-10-20',
#   'malicious': 6,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googlen.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.239',
#   'country': 'US',
#   'reg_date': '2005-08-21',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googlee.com',
#   'puny_code_domain': '',
#   'ip': '142.250.200.3',
#   'country': 'US',
#   'reg_date': '2000-04-06',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.googleb.com',
#   'puny_code_domain': '',
#   'ip': '47.254.33.193',
#   'country': 'CN',
#   'reg_date': '2010-12-28',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googleh.com',
#   'puny_code_domain': '',
#   'ip': '75.2.103.221',
#   'country': 'IM',
#   'reg_date': '2023-12-20',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.googlem.com',
#   'puny_code_domain': '',
#   'ip': '45.58.190.82',
#   'country': 'US',
#   'reg_date': '2000-11-20',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.googel.com',
#   'puny_code_domain': '',
#   'ip': '142.250.187.227',
#   'country': 'US',
#   'reg_date': '2001-01-24',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.googlek.com',
#   'puny_code_domain': '',
#   'ip': '3.64.163.50',
#   'country': '',
#   'reg_date': '2020-08-25',
#   'malicious': 6,
#   'suspicious': 1,
#   'harmless': 61},
#  {'domain': 'www.googlec.com',
#   'puny_code_domain': '',
#   'ip': '3.64.163.50',
#   'country': 'US',
#   'reg_date': '2001-02-17',
#   'malicious': 6,
#   'suspicious': 1,
#   'harmless': 61},
#  {'domain': 'www.googleg.com',
#   'puny_code_domain': '',
#   'ip': '76.223.35.103',
#   'country': 'US',
#   'reg_date': '2024-01-09',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.googlei.com',
#   'puny_code_domain': '',
#   'ip': '162.210.199.87',
#   'country': 'US',
#   'reg_date': '2003-01-17',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.googoe.com',
#   'puny_code_domain': '',
#   'ip': '66.81.203.11',
#   'country': 'US',
#   'reg_date': '2000-10-02',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 61},
#  {'domain': 'www.googlle.com',
#   'puny_code_domain': '',
#   'ip': '104.21.83.75',
#   'country': 'US',
#   'reg_date': '2000-06-29',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.googlpe.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.207',
#   'country': '',
#   'reg_date': '2003-08-24',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googhe.com',
#   'puny_code_domain': '',
#   'ip': '199.59.243.225',
#   'country': 'US',
#   'reg_date': '2002-08-08',
#   'malicious': 9,
#   'suspicious': 0,
#   'harmless': 58},
#  {'domain': 'www.googlme.com',
#   'puny_code_domain': '',
#   'ip': '116.202.118.107',
#   'country': 'US',
#   'reg_date': '2005-04-27',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.googple.com',
#   'puny_code_domain': '',
#   'ip': '103.224.212.210',
#   'country': 'US',
#   'reg_date': '2023-07-29',
#   'malicious': 10,
#   'suspicious': 0,
#   'harmless': 57},
#  {'domain': 'www.googmle.com',
#   'puny_code_domain': '',
#   'ip': '64.91.248.15',
#   'country': 'US',
#   'reg_date': '2004-02-22',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.googme.com',
#   'puny_code_domain': '',
#   'ip': '199.59.243.225',
#   'country': 'US',
#   'reg_date': '2002-08-08',
#   'malicious': 9,
#   'suspicious': 0,
#   'harmless': 58},
#  {'domain': 'www.googlke.com',
#   'puny_code_domain': '',
#   'ip': '64.32.22.102',
#   'country': '',
#   'reg_date': '2000-11-13',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.goo.gle.com',
#   'puny_code_domain': '',
#   'ip': '13.248.169.48',
#   'country': 'US',
#   'reg_date': '2001-12-29',
#   'malicious': 5,
#   'suspicious': 2,
#   'harmless': 60},
#  {'domain': 'www.goog-le.com',
#   'puny_code_domain': '',
#   'ip': '74.208.236.69',
#   'country': 'US',
#   'reg_date': '2004-11-24',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.googe.com',
#   'puny_code_domain': '',
#   'ip': '162.243.10.151',
#   'country': 'US',
#   'reg_date': '1998-10-02',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.googłe.com',
#   'puny_code_domain': 'www.xn--googe-n7a.com',
#   'ip': '46.4.60.204',
#   'country': 'TR',
#   'reg_date': '2016-02-03',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 0},
#  {'domain': 'www.goolge.com',
#   'puny_code_domain': '',
#   'ip': '216.58.212.227',
#   'country': 'US',
#   'reg_date': '1999-06-04',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'www.googvle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.207',
#   'country': '',
#   'reg_date': '2003-08-24',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.goole.com',
#   'puny_code_domain': '',
#   'ip': '217.160.0.201',
#   'country': 'GB',
#   'reg_date': '1999-11-09',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.goovle.com',
#   'puny_code_domain': '',
#   'ip': '162.210.199.65',
#   'country': 'BS',
#   'reg_date': '2017-09-23',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.goofgle.com',
#   'puny_code_domain': '',
#   'ip': '185.53.178.50',
#   'country': '',
#   'reg_date': '2004-09-23',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googfle.com',
#   'puny_code_domain': '',
#   'ip': '185.53.177.53',
#   'country': 'US',
#   'reg_date': '2008-11-13',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.googie.com',
#   'puny_code_domain': '',
#   'ip': '209.17.116.160',
#   'country': 'US',
#   'reg_date': '1998-01-21',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.goobgle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.238',
#   'country': '',
#   'reg_date': '2011-12-07',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.gooble.com',
#   'puny_code_domain': '',
#   'ip': '64.190.63.222',
#   'country': 'IS',
#   'reg_date': '1999-07-27',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 61},
#  {'domain': 'www.goofle.com',
#   'puny_code_domain': '',
#   'ip': '162.210.199.65',
#   'country': 'US',
#   'reg_date': '1999-07-30',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.gooǥle.com',
#   'puny_code_domain': 'www.xn--goole-k0b.com',
#   'ip': '216.58.201.110',
#   'country': 'US',
#   'reg_date': '2017-03-23',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 67},
#  {'domain': 'www.googble.com',
#   'puny_code_domain': '',
#   'ip': '72.52.178.23',
#   'country': 'TH',
#   'reg_date': '2002-02-19',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.goohgle.com',
#   'puny_code_domain': '',
#   'ip': '104.252.32.152',
#   'country': '',
#   'reg_date': '2023-11-03',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 0},
#  {'domain': 'www.go9gle.com',
#   'puny_code_domain': '',
#   'ip': '64.190.63.222',
#   'country': 'GE',
#   'reg_date': '2010-09-27',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 61},
#  {'domain': 'www.goowle.com',
#   'puny_code_domain': '',
#   'ip': '185.107.56.199',
#   'country': 'US',
#   'reg_date': '2020-10-18',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.googyle.com',
#   'puny_code_domain': '',
#   'ip': '93.115.28.104',
#   'country': 'PA',
#   'reg_date': '2012-04-23',
#   'malicious': 4,
#   'suspicious': 1,
#   'harmless': 62},
#  {'domain': 'www.goegle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.246',
#   'country': 'CZ',
#   'reg_date': '2000-06-24',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.googzle.com',
#   'puny_code_domain': '',
#   'ip': '52.66.233.38',
#   'country': 'CN',
#   'reg_date': '2024-01-03',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 0},
#  {'domain': 'www.gogole.com',
#   'puny_code_domain': '',
#   'ip': '216.58.204.67',
#   'country': 'US',
#   'reg_date': '2000-04-10',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 67},
#  {'domain': 'www.guogle.com',
#   'puny_code_domain': '',
#   'ip': '64.190.63.222',
#   'country': 'CA',
#   'reg_date': '2007-10-17',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 61},
#  {'domain': 'www.g.oogle.com',
#   'puny_code_domain': '',
#   'ip': '104.21.19.57',
#   'country': 'IS',
#   'reg_date': '1999-02-07',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.goagle.com',
#   'puny_code_domain': '',
#   'ip': '89.145.66.234',
#   'country': 'US',
#   'reg_date': '2004-05-08',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 0},
#  {'domain': 'www.goopgle.com',
#   'puny_code_domain': '',
#   'ip': '95.211.219.66',
#   'country': 'PA',
#   'reg_date': '2003-07-15',
#   'malicious': 2,
#   'suspicious': 1,
#   'harmless': 64},
#  {'domain': 'www.glogle.com',
#   'puny_code_domain': '',
#   'ip': '66.81.203.11',
#   'country': 'US',
#   'reg_date': '2000-10-02',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 61},
#  {'domain': 'www.gogle.com',
#   'puny_code_domain': '',
#   'ip': '142.250.200.3',
#   'country': 'US',
#   'reg_date': '1998-10-20',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.g9ogle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.238',
#   'country': '',
#   'reg_date': '2014-05-18',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.geogle.com',
#   'puny_code_domain': '',
#   'ip': '78.41.204.38',
#   'country': 'PA',
#   'reg_date': '2002-08-16',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'www.goọgle.com',
#   'puny_code_domain': 'www.xn--gogle-381b.com',
#   'ip': '217.70.184.50',
#   'country': 'FR',
#   'reg_date': '2015-10-01',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.gokogle.com',
#   'puny_code_domain': '',
#   'ip': '185.53.178.50',
#   'country': 'US',
#   'reg_date': '2007-05-05',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.gkoogle.com',
#   'puny_code_domain': '',
#   'ip': '13.248.169.48',
#   'country': 'US',
#   'reg_date': '2008-08-09',
#   'malicious': 5,
#   'suspicious': 2,
#   'harmless': 60},
#  {'domain': 'www.gpogle.com',
#   'puny_code_domain': '',
#   'ip': '69.162.95.4',
#   'country': 'BS',
#   'reg_date': '2002-03-13',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.go-ogle.com',
#   'puny_code_domain': '',
#   'ip': '66.96.149.22',
#   'country': 'US',
#   'reg_date': '2002-03-10',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.gaogle.com',
#   'puny_code_domain': '',
#   'ip': '107.180.51.12',
#   'country': 'US',
#   'reg_date': '2002-10-08',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.gioogle.com',
#   'puny_code_domain': '',
#   'ip': '185.53.178.51',
#   'country': 'IN',
#   'reg_date': '2002-10-04',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 61},
#  {'domain': 'www.gooogle.com',
#   'puny_code_domain': '',
#   'ip': '172.217.169.67',
#   'country': 'US',
#   'reg_date': '2000-03-02',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.go9ogle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.250',
#   'country': 'CN',
#   'reg_date': '2002-09-19',
#   'malicious': 3,
#   'suspicious': 2,
#   'harmless': 63},
#  {'domain': 'www.boogle.com',
#   'puny_code_domain': '',
#   'ip': '13.248.169.48',
#   'country': 'US',
#   'reg_date': '1999-06-21',
#   'malicious': 5,
#   'suspicious': 2,
#   'harmless': 60},
#  {'domain': 'www.voogle.com',
#   'puny_code_domain': '',
#   'ip': '3.64.163.50',
#   'country': '',
#   'reg_date': '2002-05-16',
#   'malicious': 6,
#   'suspicious': 1,
#   'harmless': 61},
#  {'domain': 'www.ogogle.com',
#   'puny_code_domain': '',
#   'ip': '142.250.200.35',
#   'country': 'US',
#   'reg_date': '2003-08-15',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.g0ogle.com',
#   'puny_code_domain': '',
#   'ip': '64.91.249.20',
#   'country': 'US',
#   'reg_date': '2001-10-19',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.gpoogle.com',
#   'puny_code_domain': '',
#   'ip': '104.143.9.110',
#   'country': 'US',
#   'reg_date': '2001-09-06',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 61},
#  {'domain': 'www.gopogle.com',
#   'puny_code_domain': '',
#   'ip': '173.44.37.208',
#   'country': 'US',
#   'reg_date': '2001-10-22',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.oogle.com',
#   'puny_code_domain': '',
#   'ip': '104.21.19.57',
#   'country': 'IS',
#   'reg_date': '1999-02-07',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.g9oogle.com',
#   'puny_code_domain': '',
#   'ip': '52.33.207.7',
#   'country': 'US',
#   'reg_date': '2023-04-23',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.gvoogle.com',
#   'puny_code_domain': '',
#   'ip': '103.224.182.246',
#   'country': 'CZ',
#   'reg_date': '2023-10-29',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.göogle.com',
#   'puny_code_domain': 'www.xn--gogle-jua.com',
#   'ip': '3.33.130.190',
#   'country': '',
#   'reg_date': '2019-10-30',
#   'malicious': 6,
#   'suspicious': 1,
#   'harmless': 62},
#  {'domain': 'www.vgoogle.com',
#   'puny_code_domain': '',
#   'ip': '47.254.33.193',
#   'country': 'CN',
#   'reg_date': '2009-09-26',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 63},
#  {'domain': 'www.ggoogle.com',
#   'puny_code_domain': '',
#   'ip': '142.250.178.3',
#   'country': 'US',
#   'reg_date': '2000-07-04',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.toogle.com',
#   'puny_code_domain': '',
#   'ip': '3.33.130.190',
#   'country': '',
#   'reg_date': '2001-03-30',
#   'malicious': 6,
#   'suspicious': 1,
#   'harmless': 62},
#  {'domain': 'www.gọogle.com',
#   'puny_code_domain': 'www.xn--gogle-281b.com',
#   'ip': '99.83.176.46',
#   'country': 'US',
#   'reg_date': '2021-10-13',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'www.gyoogle.com',
#   'puny_code_domain': '',
#   'ip': '199.59.243.225',
#   'country': '',
#   'reg_date': '2010-11-11',
#   'malicious': 9,
#   'suspicious': 0,
#   'harmless': 58},
#  {'domain': 'www.hgoogle.com',
#   'puny_code_domain': '',
#   'ip': '173.44.37.208',
#   'country': '',
#   'reg_date': '2000-11-09',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.bgoogle.com',
#   'puny_code_domain': '',
#   'ip': '45.58.190.82',
#   'country': 'US',
#   'reg_date': '2003-04-18',
#   'malicious': 3,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.gboogle.com',
#   'puny_code_domain': '',
#   'ip': '185.107.56.202',
#   'country': 'PA',
#   'reg_date': '2002-09-19',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.zoogle.com',
#   'puny_code_domain': '',
#   'ip': '192.254.233.61',
#   'country': 'US',
#   'reg_date': '2001-06-01',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 51},
#  {'domain': 'www.yoogle.com',
#   'puny_code_domain': '',
#   'ip': '127.0.0.1',
#   'country': 'US',
#   'reg_date': '2000-01-31',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.tgoogle.com',
#   'puny_code_domain': '',
#   'ip': '198.251.81.30',
#   'country': 'US',
#   'reg_date': '2001-10-22',
#   'malicious': 2,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.fgoogle.com',
#   'puny_code_domain': '',
#   'ip': '127.0.0.10',
#   'country': 'PA',
#   'reg_date': '2001-08-29',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.google.in',
#   'puny_code_domain': '',
#   'ip': '216.58.204.67',
#   'country': 'US',
#   'reg_date': '2012-01-27',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 67},
#  {'domain': 'www.google.ru',
#   'puny_code_domain': '',
#   'ip': '142.250.178.3',
#   'country': 'US',
#   'reg_date': '2012-05-24',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.ĝoogle.com',
#   'puny_code_domain': 'www.xn--oogle-60a.com',
#   'ip': '64.225.91.73',
#   'country': 'US',
#   'reg_date': '2023-07-10',
#   'malicious': 5,
#   'suspicious': 0,
#   'harmless': 60},
#  {'domain': 'www.google.ml',
#   'puny_code_domain': '',
#   'ip': '142.250.187.227',
#   'country': 'US',
#   'reg_date': '2012-05-24',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.foogle.com',
#   'puny_code_domain': '',
#   'ip': '173.236.255.36',
#   'country': 'US',
#   'reg_date': '1999-06-27',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 0},
#  {'domain': 'www.google.io',
#   'puny_code_domain': '',
#   'ip': '142.250.180.3',
#   'country': 'US',
#   'reg_date': '2012-05-24',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 65},
#  {'domain': 'www.google.cf',
#   'puny_code_domain': '',
#   'ip': '142.250.200.3',
#   'country': 'US',
#   'reg_date': '2012-05-24',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'www.woogle.com',
#   'puny_code_domain': '',
#   'ip': '64.98.135.11',
#   'country': 'RU',
#   'reg_date': '2002-04-14',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 62},
#  {'domain': 'www.googlecom.com',
#   'puny_code_domain': '',
#   'ip': '172.217.16.227',
#   'country': 'US',
#   'reg_date': '2000-04-28',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'account-verify-google.com',
#   'puny_code_domain': '',
#   'ip': '65.108.50.121',
#   'country': 'IL',
#   'reg_date': '2023-09-04',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 0},
#  {'domain': 'www.google.ga',
#   'puny_code_domain': '',
#   'ip': '216.58.212.195',
#   'country': 'US',
#   'reg_date': '2012-01-27',
#   'malicious': 1,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'www.google.com',
#   'puny_code_domain': '',
#   'ip': '142.250.200.36',
#   'country': 'US',
#   'reg_date': '1997-09-15',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 66},
#  {'domain': 'login-google.com',
#   'puny_code_domain': '',
#   'ip': '20.42.95.243',
#   'country': 'US',
#   'reg_date': '2016-10-18',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 0},
#  {'domain': 'www.google.cn',
#   'puny_code_domain': '',
#   'ip': '216.58.201.99',
#   'country': 'US',
#   'reg_date': '2012-01-27',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 67},
#  {'domain': 'www.google.info',
#   'puny_code_domain': '',
#   'ip': '142.250.179.227',
#   'country': 'US',
#   'reg_date': '2001-07-31',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 64},
#  {'domain': 'auth-google.com',
#   'puny_code_domain': '',
#   'ip': '128.199.247.177',
#   'country': 'US',
#   'reg_date': '2019-06-13',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 61},
#  {'domain': 'security-google.com',
#   'puny_code_domain': '',
#   'ip': '142.250.180.14',
#   'country': 'cn',
#   'reg_date': '2014-06-17',
#   'malicious': 0,
#   'suspicious': 0,
#   'harmless': 65}]

# %% [markdown]
# # Code for Levenshtein Distance

# %%
import Levenshtein

LEVENSHTEIN_THRESHOLD = 4

class LevenshteinDistance:
    """
        This Class calculates Levenshtein Distance and 
        sort the domain list
        
        Attribute:
        domain: str
                domain that need to be searched for
                Typosquatting related entries

        domain_data: list
                    all typesquated scraped domain data
    """
    def __init__(self, domain_data, domain):
        self.domain_data = domain_data
        self.domain = domain

    def domain_levenshtein_sort(self):
        """
            This Method calculates the levenstein distance and sort the domain 
            details list with ascending order of levenshtein distance by removing
            domains with levenshtein distance greater than the LEVENSTEIN_THRESHOLD 
        
        """
        output_data = []
        for item in self.domain_data:
            distance = Levenshtein.distance(self.domain, item["domain"])
            if distance <= LEVENSHTEIN_THRESHOLD and item["domain"] != self.domain:
                item['levenshtein_distance'] = distance
                output_data.append(item)
        sorted_data = sorted(output_data, key=lambda x: x['levenshtein_distance'])
        return sorted_data
    
if __name__ == '__main__':
    data = LevenshteinDistance(l_d_input,'www.google.com').domain_levenshtein_sort()
    print(data)
# Out:
# [{'domain': 'ww.google.com', 'puny_code_domain': '', 'ip': '142.250.200.46', 'country': 'US', 'reg_date': '1997-09-15', 'malicious': 0, 'suspicious': 0, 'harmless': 67, 'levenshtein_distance': 1}, {'domain': 'www.google.co', 'puny_code_domain': '', 'ip': '142.250.187.206', 'country': 'US', 'reg_date': '2012-05-24', 'malicious': 0, 'suspicious': 0, 'harmless': 66, 'levenshtein_distance': 1}, {'domain': 'wwwngoogle.com', 'puny_code_domain': '', 'ip': '199.59.243.225', 'country': '', 'reg_date': '2011-05-16', 'malicious': 9, 'suspicious': 0, 'harmless': 58, 'levenshtein_distance': 1}, {'domain': 'wwwgoogle.com', 'puny_code_domain': '', 'ip': '216.58.212.228', 'country': 'US', 'reg_date': '1999-03-03', 'malicious': 2, 'suspicious': 0, 'harmless': 64, 'levenshtein_distance': 1}, {'domain': 'www.go0ogle.com', 'puny_code_domain': '', 'ip': '95.211.189.138', 'country': 'PA', 'reg_date': '2002-09-01', 'malicious': 1, 'suspicious': 0, 'harmless': 64, 'levenshtein_distance': 1}, {'domain': 'www.gookgle.com', 'puny_code_domain': '', 'ip': '103.224.182.226', 'country': '', 'reg_date': '2008-07-21', 'malicious': 2, 'suspicious': 0, 'harmless': 62, 'levenshtein_distance': 1}, {'domain': 'www.googlwe.com', 'puny_code_domain': '', 'ip': '95.211.189.137', 'country': 'US', 'reg_date': '2000-11-13', 'malicious': 0, 'suspicious': 1, 'harmless': 65, 'levenshtein_distance': 1}, {'domain': 'www.googloe.com', 'puny_code_domain': '', 'ip': '78.41.204.34', 'country': 'US', 'reg_date': '2000-11-09', 'malicious': 0, 'suspicious': 0, 'harmless': 67, 'levenshtein_distance': 1}, {'domain': 'www.goozle.com', 'puny_code_domain': '', 'ip': '50.62.97.1', 'country': 'US', 'reg_date': '1999-10-04', 'malicious': 0, 'suspicious': 0, 'harmless': 0, 'levenshtein_distance': 1}, {'domain': 'www.goohle.com', 'puny_code_domain': '', 'ip': '47.254.33.193', 'country': 'CN', 'reg_date': '2002-06-03', 'malicious': 1, 'suspicious': 0, 'harmless': 63, 'levenshtein_distance': 1}, {'domain': 'www.googl.com', 'puny_code_domain': '', 'ip': '172.217.16.227', 'country': 'US', 'reg_date': '2001-01-24', 'malicious': 0, 'suspicious': 0, 'harmless': 66, 'levenshtein_distance': 1}, {'domain': 'www.gooyle.com', 'puny_code_domain': '', 'ip': '66.81.203.201', 'country': 'US', 'reg_date': '2000-10-02', 'malicious': 0, 'suspicious': 0, 'harmless': 63, 'levenshtein_distance': 1}, {'domain': 'www.googlde.com', 'puny_code_domain': '', 'ip': '13.248.169.48', 'country': 'US', 'reg_date': '2002-12-01', 'malicious': 5, 'suspicious': 2, 'harmless': 60, 'levenshtein_distance': 1}, {'domain': 'www.googlr.com', 'puny_code_domain': '', 'ip': '142.250.187.195', 'country': 'US', 'reg_date': '2001-05-29', 'malicious': 1, 'suspicious': 0, 'harmless': 65, 'levenshtein_distance': 1}, {'domain': 'www.gootle.com', 'puny_code_domain': '', 'ip': '66.81.203.201', 'country': 'US', 'reg_date': '2000-10-02', 'malicious': 0, 'suspicious': 0, 'harmless': 63, 'levenshtein_distance': 1}, {'domain': 'www.googl4.com', 'puny_code_domain': '', 'ip': '103.224.182.245', 'country': '', 'reg_date': '2007-10-04', 'malicious': 0, 'suspicious': 0, 'harmless': 66, 'levenshtein_distance': 1}, {'domain': 'www.googli.com', 'puny_code_domain': '', 'ip': '162.255.119.253', 'country': 'CN', 'reg_date': '2012-09-04', 'malicious': 0, 'suspicious': 0, 'harmless': 54, 'levenshtein_distance': 1}, {'domain': 'www.googlè.com', 'puny_code_domain': 'www.xn--googl-8ra.com', 'ip': '217.160.0.119', 'country': 'FR', 'reg_date': '2023-12-21', 'malicious': 0, 'suspicious': 0, 'harmless': 64, 'levenshtein_distance': 1}, {'domain': 'www.googlě.com', 'puny_code_domain': 'www.xn--googl-z0a.com', 'ip': '213.186.33.5', 'country': 'FR', 'reg_date': '2022-01-14', 'malicious': 2, 'suspicious': 0, 'harmless': 65, 'levenshtein_distance': 1}, {'domain': 'www.google4.com', 'puny_code_domain': '', 'ip': '185.53.177.54', 'country': '', 'reg_date': '2004-06-11', 'malicious': 2, 'suspicious': 0, 'harmless': 62, 'levenshtein_distance': 1}, {'domain': 'www.googlė.com', 'pun ...

# %%
ld_df = pd.DataFrame(data)
ld_df
# Out:
#                 domain puny_code_domain               ip country    reg_date  \
# 0        ww.google.com                    142.250.200.46      US  1997-09-15
# 1        www.google.co                   142.250.187.206      US  2012-05-24
# 2       wwwngoogle.com                    199.59.243.225          2011-05-16
# 3        wwwgoogle.com                    216.58.212.228      US  1999-03-03
# 4      www.go0ogle.com                    95.211.189.138      PA  2002-09-01
# ..                 ...              ...              ...     ...         ...
# 124      www.google.ru                     142.250.178.3      US  2012-05-24
# 125      www.google.ml                   142.250.187.227      US  2012-05-24
# 126  www.googlecom.com                    172.217.16.227      US  2000-04-28
# 127      www.google.ga                    216.58.212.195      US  2012-01-27
# 128    www.google.info                   142.250.179.227      US  2001-07-31
#
#      malicious  suspicious  harmless  levenshtein_distance
# 0            0           0        67                     1
# 1            0           0        66                     1
# 2            9           0        58                     1
# 3            2           0        64                     1
# 4            1           0        64                     1
# ..         ...         ...       ...                   ...
# 124          0           0        65                     3
# 125          0           0        65                     3
# 126          0           0        66                     3
# 127          1           0        66                     3
# 128          0           0        64                     4
#
# [129 rows x 9 columns]

# %% [markdown]
# # Code to categorise the domains into benign, suspicious and malicious according to a grading of your own choosing, given the VT report per domain, the registration details and Levenshtein distance to genuine domain.
#
# ## Logic:
# ### 1) Malicious: Data which have atleast one malicious report as per VT report are categorised as malicious.
# ### 2) Suspicious:  Four data's are considered and if any of the contition matches, domain is considered as suspicious.
# #### a) If atleast one report for suspicious in VT report.
# #### b) If the levenshtein distance is less than or equal to 2.
# #### c) If the registration date of the typesquatted domain is after the threshold registration date. Threshold date is taken on the basis of when the original domain became public and profitable.
# #### d) If the typesquatted domain location belongs to a suspecious country.
# ### 3) Benign: Rest of the domain are assumed as benign.

# %%
from datetime import datetime

SUSPICIOUS_COUNTRIES = ["KR"]

class CategoriseDomain:
    """
        This class categorises the domain
        
        Attribute:
        reg_date_threshold: str
                            date on which the domain
                            become popular and profitable
        domain_data: list
                    all typesquated scraped domain data
    """
    def __init__(self, domain_data, reg_date_threshold):
        self.domain_data = domain_data
        self.reg_date_threshold = datetime.strptime(reg_date_threshold, '%Y-%m-%d')
        
    def categorise_domain(self) -> list:
        """
            This method categorises the domain based on multiple conditions
        """
        categorise_data = []
        for item in self.domain_data:
            reg_date_flag = self.check_registration_date(item["reg_date"])
            reg_country_flag = self.check_registered_country(item["country"])
            if item["malicious"] > 0:
                categorise_data.append({"domain":item["domain"],"category":"malicious"})
            elif item["suspicious"] > 0 or item["levenshtein_distance"] <= 2 \
                    or reg_date_flag or reg_country_flag:
                categorise_data.append({"domain":item["domain"],"category":"suspicious"})
            else:
                categorise_data.append({"domain":item["domain"],"category":"benign"})
        return categorise_data
    
    def check_registration_date(self, registration_date) -> bool:
        """
            This method checks if the domain's registration 
            date is less than the threshold registration date
        """
        if registration_date != '':
            registration_date = datetime.strptime(registration_date, '%Y-%m-%d')
            if registration_date > self.reg_date_threshold:
                return True
        return False
    
    def check_registered_country(self, country) -> bool:
        """
            This method checks if the domain's registration 
            country belongs to suspicious countries list
        """
        if country in SUSPICIOUS_COUNTRIES:
            return True
        return False

if __name__ == "__main__":
    # The domain www.google.com went public in 2004 and became profitable 
    # in the same year, henced used 2004-01-01 as a threshold date here
    reg_date_threshold = '2004-01-01'
    category_data = CategoriseDomain(data, reg_date_threshold).categorise_domain()
    print(category_data)
# Out:
# [{'domain': 'ww.google.com', 'category': 'suspicious'}, {'domain': 'www.google.co', 'category': 'suspicious'}, {'domain': 'wwwngoogle.com', 'category': 'malicious'}, {'domain': 'wwwgoogle.com', 'category': 'malicious'}, {'domain': 'www.go0ogle.com', 'category': 'malicious'}, {'domain': 'www.gookgle.com', 'category': 'malicious'}, {'domain': 'www.googlwe.com', 'category': 'suspicious'}, {'domain': 'www.googloe.com', 'category': 'suspicious'}, {'domain': 'www.goozle.com', 'category': 'suspicious'}, {'domain': 'www.goohle.com', 'category': 'malicious'}, {'domain': 'www.googl.com', 'category': 'suspicious'}, {'domain': 'www.gooyle.com', 'category': 'suspicious'}, {'domain': 'www.googlde.com', 'category': 'malicious'}, {'domain': 'www.googlr.com', 'category': 'malicious'}, {'domain': 'www.gootle.com', 'category': 'suspicious'}, {'domain': 'www.googl4.com', 'category': 'suspicious'}, {'domain': 'www.googli.com', 'category': 'suspicious'}, {'domain': 'www.googlè.com', 'category': 'suspicious'}, {'domain': 'www.googlě.com', 'category': 'malicious'}, {'domain': 'www.google4.com', 'category': 'malicious'}, {'domain': 'www.googlė.com', 'category': 'malicious'}, {'domain': 'www.googlez.com', 'category': 'malicious'}, {'domain': 'www.googlze.com', 'category': 'malicious'}, {'domain': 'www.googlé.com', 'category': 'malicious'}, {'domain': 'www.googlz.com', 'category': 'malicious'}, {'domain': 'www.googleq.com', 'category': 'malicious'}, {'domain': 'www.googlê.com', 'category': 'suspicious'}, {'domain': 'www.googlm.com', 'category': 'suspicious'}, {'domain': 'www.googley.com', 'category': 'suspicious'}, {'domain': 'www.googlet.com', 'category': 'malicious'}, {'domain': 'www.googlew.com', 'category': 'malicious'}, {'domain': 'www.googlen.com', 'category': 'malicious'}, {'domain': 'www.googlee.com', 'category': 'suspicious'}, {'domain': 'www.googleb.com', 'category': 'malicious'}, {'domain': 'www.googleh.com', 'category': 'suspicious'}, {'domain': 'www.googlem.com', 'category': 'malicious'}, {'domain': 'www.googlek.com', 'category': 'malicious'}, {'domain': 'www.googlec.com', 'category': 'malicious'}, {'domain': 'www.googleg.com', 'category': 'malicious'}, {'domain': 'www.googlei.com', 'category': 'malicious'}, {'domain': 'www.googoe.com', 'category': 'suspicious'}, {'domain': 'www.googlle.com', 'category': 'suspicious'}, {'domain': 'www.googlpe.com', 'category': 'malicious'}, {'domain': 'www.googhe.com', 'category': 'malicious'}, {'domain': 'www.googlme.com', 'category': 'suspicious'}, {'domain': 'www.googple.com', 'category': 'malicious'}, {'domain': 'www.googmle.com', 'category': 'malicious'}, {'domain': 'www.googme.com', 'category': 'malicious'}, {'domain': 'www.googlke.com', 'category': 'suspicious'}, {'domain': 'www.goo.gle.com', 'category': 'malicious'}, {'domain': 'www.goog-le.com', 'category': 'suspicious'}, {'domain': 'www.googe.com', 'category': 'malicious'}, {'domain': 'www.googłe.com', 'category': 'suspicious'}, {'domain': 'www.googvle.com', 'category': 'malicious'}, {'domain': 'www.goole.com', 'category': 'suspicious'}, {'domain': 'www.goovle.com', 'category': 'malicious'}, {'domain': 'www.goofgle.com', 'category': 'malicious'}, {'domain': 'www.googfle.com', 'category': 'malicious'}, {'domain': 'www.googie.com', 'category': 'malicious'}, {'domain': 'www.goobgle.com', 'category': 'malicious'}, {'domain': 'www.gooble.com', 'category': 'malicious'}, {'domain': 'www.goofle.com', 'category': 'malicious'}, {'domain': 'www.gooǥle.com', 'category': 'suspicious'}, {'domain': 'www.googble.com', 'category': 'malicious'}, {'domain': 'www.goohgle.com', 'category': 'suspicious'}, {'domain': 'www.go9gle.com', 'category': 'malicious'}, {'domain': 'www.goowle.com', 'category': 'malicious'}, {'domain': 'www.googyle.com', 'category': 'malicious'}, {'domain': 'www.goegle.com', 'category': 'malicious'}, {'domain': 'www.googzle.com', 'category': 'suspicious'}, {'domain': 'www.guogle.com', 'category': 'malicious'}, {'domain': 'www.g.oogle.com', 'catego ...

# %%
c_df = pd.DataFrame(category_data)
#total count in diffrent categories
c_df["category"].value_counts()
# Out:
# category
# malicious     73
# suspicious    52
# benign         4
# Name: count, dtype: int64

# %%
c_df
# Out:
#                 domain    category
# 0        ww.google.com  suspicious
# 1        www.google.co  suspicious
# 2       wwwngoogle.com   malicious
# 3        wwwgoogle.com   malicious
# 4      www.go0ogle.com   malicious
# ..                 ...         ...
# 124      www.google.ru  suspicious
# 125      www.google.ml  suspicious
# 126  www.googlecom.com      benign
# 127      www.google.ga   malicious
# 128    www.google.info      benign
#
# [129 rows x 2 columns]
